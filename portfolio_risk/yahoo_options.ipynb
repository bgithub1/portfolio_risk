# %% [markdown]
# ## yahoo_options
# The yahoo_options notebook gives examples for usying the yfinance package to access historical data for options of stocks, as wells as their underlyings.

# %%
import yfinance as yf
import datetime
import pandas as pd
import numpy as np
from lxml import html
import requests
import py_vollib.black.implied_volatility as pvol
import py_vollib.black as black
import pdb
from IPython import display
import plotly_utilities as pu

import ftplib
import zipfile
import os
import curl_cffi
import re
# Out:
# /Users/bperlman1/Virtualenvs3/risktables/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
class BCOLORS:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

def error_print(mess,end=None):
    if end is None:
        print(BCOLORS.FAIL + BCOLORS.BOLD + mess + BCOLORS.ENDC)
    else:
        print(BCOLORS.FAIL + BCOLORS.BOLD + mess + BCOLORS.ENDC,end=end)

def display_df_large_fields(df,col_size=50):
    '''
    Display a dataframe without truncating number field types
    '''
    with pd.option_context('display.max_colwidth',col_size):
        display.display(df)

# %%
def display_df_large_numbers(df,rounding=5,g_size=10):
    '''
    Display a dataframe without truncating number field types
    '''
    with pd.option_context('display.float_format',lambda x: f'%.{g_size}g' % x):
        display(df)


def display_all_rows(df,num_rows=None):
    nr = len(df) if num_rows is None else num_rows
    with pd.option_context("display.max_rows", nr):
        display(df)

# %%
def get_yyyymmdd(td):
    tds = str(td)[0:10]
    tds = tds.replace('-','')
    return int(tds)

def get_pc(sym):
    l = len(sym) - 15 
    return sym[l+6]

def get_implied_price(df_options,use_mid=True):
    strikes = [
        s for s in df_options.strike.unique()
        if len(df_options[df_options.strike==s])==2
    ]
    min_strike = min(strikes)
    c1 = df_options.strike==min_strike
    c2 = df_options.pc == 'C'
    df_min_strike_call = df_options[c1 & c2]
    c2 = df_options.pc == 'P'
    df_min_strike_put = df_options[c1 & c2]
    if use_mid:
        call_mid = (df_min_strike_call.bid.values[0] + df_min_strike_call.ask.values[0])/2
        put_mid = (df_min_strike_put.bid.values[0] + df_min_strike_put.ask.values[0])/2    
        underlying = call_mid + min_strike - put_mid
    else:
        call_last = df_min_strike_call.lastPrice.values[0]
        put_last = df_min_strike_put.lastPrice.values[0]
        underlying = call_last + min_strike - put_last
    return underlying

def calc_implied_vol(strike,opt_price,und_price,dte_perc_of_year,rate,pc):
    try:
        iv = pvol.implied_volatility(opt_price,und_price,strike,rate,dte_perc_of_year,pc)
    except Exception as e:
        print(f"Exception: {row}")
        return None
    return iv
    
def implied_vol(row):
    opt_price = row.option
    und_price = row.underlying
    row_date = datetime.datetime(
        row.name.year,row.name.month,row.name.day)
    dte = row.expiry_date - row_date
    # convert dte from a numpy.datetime64 to a datetime.datetime object
    if len(re.findall('[0-9]{2}',str(type(dte))))>0:
        dte = dte.item()

    try:
        dte = dte.days/365
    except:
        dte = dte.item()
        dte = dte.days/365
        
    rate = row.rate
    try:
        pc = row.pc.lower()
    except Exception as e:
        if 'series' not in str(type(row.pc)).lower():
            raise ValueError(str(e))
        pc = str(row.pc.values[0]).lower()
        
    strike = row.strike
    try:
        iv = pvol.implied_volatility(opt_price,und_price,strike,rate,dte,pc)
    except Exception as e:
        pdb.set_trace()
        print(f"Exception: {row}")
        return None
    return iv

def exp_string_to_datetime(exp_string):
    return datetime.datetime(
        int(exp_string[0:2])+2000,
        int(exp_string[2:4]),
        int(exp_string[4:6])
    )

def yf_download(symbol,dtb,dte,auto_adjust=False):
    _df = yf.download(symbol,dtb,dte,auto_adjust=auto_adjust)
    _df.columns = _df.columns.get_level_values(0)
    _df['sym'] = symbol
    return _df

def yf_multi_download(list_symbol,dtb,dte,auto_adjust=False):
    _df = yf.download(list_symbol,dtb,dte,auto_adjust=auto_adjust)
    # _df.columns = _df.columns.get_level_values(0)
    # _df['sym'] = symbol
    return _df


def exp_datetime_to_exp_string(exp_dt):
    year = exp_dt.year
    month = exp_dt.month
    day = exp_dt.day
    yyyymmdd = year*100*100 + month*100 + day
    return str(yyyymmdd)[-6:]

def get_opt_sym(under_sym,pc,strike,dt_expiry,round_strike_to_zero=True):
    if round_strike_to_zero:
        strike = round(strike,0)
    str_strk = str(strike).replace('.','')
    len_strk = len(str_strk)
    trailing_zero_size = 6-len_strk
    trailing_zero_multiplier = 10**trailing_zero_size
    # s = f'00000000{str(int(int(strike)*1000))}'[-8:]
    s = f'00000000{str(int(str_strk)*trailing_zero_multiplier)}'[-8:]
    exp_date_string = exp_datetime_to_exp_string(dt_expiry)
    op_sym = f'{str(under_sym).upper()}{exp_date_string}{str(pc).upper()}{s}'
    return op_sym

def get_option_syms_per_time(df_under_sym,dt_beg,dt_end):
    pass
    
class YahooOptions:
    def __init__(self,symbol,dte=None,days_of_hist=100,round_to=0):
        self.symbol = symbol
        session = curl_cffi.requests.Session(impersonate="chrome")
        self.ticker = yf.Ticker(symbol, session=session)
        self.ticker_options_chain = self.ticker.option_chain(date=None)
        self.expirations = self.ticker._expirations
        self.dte = datetime.datetime.now() if dte is None else dte
        self.dtb = self.dte - datetime.timedelta(days_of_hist)
        # self.df_und_hist = yf.download(symbol,self.dtb,self.dte,auto_adjust=False)
        self.df_und_hist = yf_download(symbol,self.dtb,self.dte,auto_adjust=False)
        self.prev_close = self.df_und_hist.iloc[-1].Close
        
    def get_options(self,exp_date_string):
        expirations = list(self.expirations.keys())
        if exp_date_string not in expirations:
            raise(ValueError(f"expiry {exp_date_string} not in {expirations} "))
        symbol = self.symbol
        ticker = self.ticker
        ticker_options_chain = ticker.option_chain(date=exp_date_string)
        df_ticker_options = pd.DataFrame()
        # for df in ticker_options_chain:
        #     df_ticker_options = pd.concat([df_ticker_options,df])
        df_ticker_options = pd.concat(ticker_options_chain,ignore_index=True)

        df_ticker_options['pc'] = df_ticker_options.contractSymbol.apply(get_pc)
        df_ticker_options['td_yyyymmdd'] = df_ticker_options.lastTradeDate.apply(get_yyyymmdd)
        return df_ticker_options
    
    

    def get_options_all_strikes_in_hist(
        self,expiry_datetime,strikes_to_get=None,pc='C',rounding=0,
        extended_strike_range_perc = 0.05
    ):
        exp_date_string = exp_datetime_to_exp_string(expiry_datetime)
        dte = self.dte
        dtb = self.dtb
        strikes_to_fetch = strikes_to_get
        if strikes_to_fetch is None:
            strikes_to_fetch = sorted(
                [
                    int(v.round(rounding))
                    for v in self.df_und_hist.Close.values
                ]
            )
            
        dfu = self.df_und_hist
        # df_all_op = pd.DataFrame()
        _list_df_all_op = []
        for strike in strikes_to_fetch:
            s = f'00000000{str(int(int(strike)*1000))}'[-8:]
            sym = f'{self.symbol}{exp_date_string}{pc}{s}'
            # dfo = yf.download(sym,dtb,dte,auto_adjust=False)
            dfo = yf_download(sym,dtb,dte,auto_adjust=False)
            if len(dfo)<1:
                continue
            
            dfb = dfo.rename(columns={'Close':'option'}).merge(
                dfu[['Close']].rename(columns={'Close':'underlying'}),on='Date')
            dfb['strike'] = strike
            dfb['pc'] = pc
            dfb['expiry_date'] = expiry_datetime
            dfb['rate'] = .04
            # df_all_op = pd.concat([df_all_op,dfb])    
            _list_df_all_op.append(dfb)
        df_all_op = pd.concat(_list_df_all_op)
        df_all_op['iv'] = df_all_op.apply(implied_vol,axis=1)
        
        df_all_op = df_all_op.rename(
            columns = {
                c:c.lower().replace(' ','_') 
                for c in df_all_op.columns.values
            }
        )
        return df_all_op

    def select_atm_options_only(self,df_all_op):
        '''
        @param df_all_op: The DataFrame that the method get_options_all_strikes_in_hist
                            returns
        '''
        df_all_op['afm'] = df_all_op.strike - df_all_op.underlying
        df_all_op['afm'] = df_all_op['afm'].abs()
        df_all_op_gb = df_all_op[
            ['afm']
        ].groupby(
            by=[df_all_op.index],
        ).min()
        
        df_opt_all_2 = df_all_op.merge(
            df_all_op_gb,left_index=True,right_index=True,how='left'
        )
        df_opt_all_2 =  df_opt_all_2[df_opt_all_2.afm_x==df_opt_all_2.afm_y]
        df_opt_all_2 = df_opt_all_2.drop_duplicates()
        return df_opt_all_2

# %%
get_opt_sym('SPY','c',635.5,_dt_expiry)
# Out:
# 'SPY250822C00636000'

# %%
_dt_expiry = datetime.datetime.now()-datetime.timedelta(1)
_op_sym = get_opt_sym('SPY','c',635.5,_dt_expiry)
_dt_end = datetime.datetime.now()
_dt_beg = _dt_end - datetime.timedelta(5)
# _df_opt = yf_download(_op_sym,_dt_beg,_dt_end)
# display.display(_df_opt)
_list_opt_sym = [get_opt_sym('SPY','c',strk,_dt_expiry) for strk in [635.5-12,635.5-6,635.5+6,635.5+12]]
_list_opt_sym
_df_opt_multi = yf_multi_download(_list_opt_sym,_dt_beg,_dt_end)
_col_lev_0 = 'Open'
list_col_tuple_open = [
    (_col_lev_0,opt_sym)
    for opt_sym in _list_opt_sym
]
_col_lev_0 = 'Close'
list_col_tuple_close = [
    (_col_lev_0,opt_sym)
    for opt_sym in _list_opt_sym
]
list_col_tuple = list_col_tuple_open + list_col_tuple_close
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
_row = _df_opt_multi.loc[:,list_col_tuple].iloc[1]
[_row[_tup] for _tup in list_col_tuple]
_row.to_dict()
_df_opt_multi.loc[:,list_col_tuple]
_dates = _df_opt_multi.index.values
_df_opt_multi.loc[_dates[0:2],'Close']
# Out:
# Ticker      SPY250822C00624000  SPY250822C00630000  SPY250822C00642000  \
# Date
# 2025-08-18           19.500000               14.39                4.34
# 2025-08-19           16.360001               11.04                2.30
#
# Ticker      SPY250822C00648000
# Date
# 2025-08-18                1.39
# 2025-08-19                0.44

# %%
200000/(4/100),200000/4*100
# Out:
# (5000000.0, 5000000.0)

# %%
def get_df_condor_strikes(df,lev_0_price_col,underlying_symbol_col,annual_vol_col,days_of_vol):
    '''
    @param df: a dataframe with multiIndex columns that have 2 levels, where: 
        * level 0 = a price type like Open, High, Low, Close, Volume
        * level 1 = 2 column index where:
            column 0 = symbol of underlying (like 'SPY'), which holds the prices from level 0
            column 1 = 'annualized_vol' to use to create condor strikes
    @param lev_0_price_col: the level 0 index to use to get prices
    @param vol_col: the level 0 column to use for values that hold annualized vols (standard deviations)
    @param days_of_vol: the "deannualization" value to bring the vol a daily, weekly, month, etc vol - as opposed to an annual vol
        * vol_deannulaized = vol_annual/days**.5
    @return a dataframe with singleIndex columns which include - for each row - the 
    '''
    # get single level df
    _df = df.loc[:,lev_0_price_col].copy()
    _df = _df.rename(columns={underlying_symbol:'underlying_price',annual_vol_col:'annual_vol_col'})

    # create de-annualized vol
    _df['deannualized_vol'] = _df['annual_vol_col'] * round(days_of_vol/252**.5,4)

    def round_to_base(x, base=5):
        return int(base * round(float(x)/base))    
    
    # get strike distance
    _df['strike_dist'] = round(_df['deannualized_vol']/10 * _df['underlying_price'],1)
    _df['strike_dist'] = _df['strike_dist'].apply(round_to_base)/10

    # get condor strikes
    def _condor_strike(row,strike_dist_multiplier):
        # strike = round_to_base(row.underlying_price) + row.strike_dist*strike_dist_multiplier
        strike = round(row.underlying_price,0) + row.strike_dist*strike_dist_multiplier
        return strike

    _df['put_2'] = _df.apply(lambda row: _condor_strike(row,-2),axis=1)
    _df['put_1'] = _df.apply(lambda row: _condor_strike(row,-1),axis=1)
    _df['call_1'] = _df.apply(lambda row: _condor_strike(row,1),axis=1)
    _df['call_2'] = _df.apply(lambda row: _condor_strike(row,2),axis=1)
    return _df

def get_df_spy_condor_strikes(
    dt_beg,dt_end,
    lev_0_price_col='Open',
    underlying_symbol_col = 'SPY',
    annualized_vol_col = '^VIX',
    days_of_vol = 1
):
    '''
    Get a Dataframe with columns:
        underlying_price:  like 'SPY'
        annual_vol_col:    like 16, for 16%)
        deannualized_vol:  like 1, for 1% if the annual_vol = 16 because 16 * 1/252**(1/2) ~= 1
        put_2:             the low strike of the the put spread of the condor
        put_1:             the high strike of the the put spread of the condor
        call_1:            the low strike of the the call spread of the condor   
        call_2:            the high strike of the the call spread of the condor
        sym_put_2:         yahoo options symbol for put_2
        sym_put_1:         yahoo options symbol for put_1
        sym_call_1:        yahoo options symbol for call_1 
        sym_call_2:        yahoo options symbol for call_2 
    
    '''
    
    df_spy = yf_multi_download(['SPY','^VIX'],dt_beg,dt_end)
    df_condor_strikes = get_df_condor_strikes(df_spy,_lev_0_price_col,_underlying_symbol_col,_annualized_vol_col,_days_of_vol)
    def _get_strike_yf_symbol(row,condor_strike_col):
        pc = 'p' if ('put' in condor_strike_col.lower()) else 'c'
        dt_expiry = row.name
        return get_opt_sym('SPY',pc,row[condor_strike_col],dt_expiry)
    
    for _condor_strike_col in ['put_2','put_1','call_1','call_2']:
        df_condor_strikes['sym_' + _condor_strike_col] = df_condor_strikes.apply(
            lambda row:_get_strike_yf_symbol(row,_condor_strike_col),axis=1)
    
    return df_condor_strikes

_dt_end = datetime.datetime.now()
_dt_beg = _dt_end - datetime.timedelta(70)
_df_spy_condor_info = get_df_spy_condor_strikes(_dt_beg,_dt_end)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
_df_spy_condor_info
# Out:
# Ticker      underlying_price  annual_vol_col  deannualized_vol  strike_dist  \
# Date
# 2025-06-16        600.400024       19.780001           1.24614          7.5
# 2025-06-17        600.210022       20.530001           1.29339          8.0
# 2025-06-18        598.440002       20.900000           1.31670          8.0
# 2025-06-20        598.380005       20.740000           1.30662          8.0
# 2025-06-23        595.039978       21.150000           1.33245          8.0
# 2025-06-24        604.330017       18.190001           1.14597          7.0
# 2025-06-25        607.909973       17.280001           1.08864          6.5
# 2025-06-26        608.989990       16.670000           1.05021          6.5
# 2025-06-27        612.880005       16.309999           1.02753          6.5
# 2025-06-30        617.380005       17.190001           1.08297          6.5
# 2025-07-01        616.359985       16.980000           1.06974          6.5
# ...

# %%
# get list of friday datetime's
current_date = datetime.datetime(2025,1,1)
while current_date.weekday() != 4:  # 4 represents Friday (Monday is 0)
    current_date += datetime.timedelta(days=1)
fridays = []
end_date = datetime.datetime.now()
while current_date <= end_date:
    fridays.append(current_date)
    current_date += datetime.timedelta(weeks=1)  # Move to the next Friday
fridays
# Out:
# [datetime.datetime(2025, 1, 3, 0, 0),
#  datetime.datetime(2025, 1, 10, 0, 0),
#  datetime.datetime(2025, 1, 17, 0, 0),
#  datetime.datetime(2025, 1, 24, 0, 0),
#  datetime.datetime(2025, 1, 31, 0, 0),
#  datetime.datetime(2025, 2, 7, 0, 0),
#  datetime.datetime(2025, 2, 14, 0, 0),
#  datetime.datetime(2025, 2, 21, 0, 0),
#  datetime.datetime(2025, 2, 28, 0, 0),
#  datetime.datetime(2025, 3, 7, 0, 0),
#  datetime.datetime(2025, 3, 14, 0, 0),
#  datetime.datetime(2025, 3, 21, 0, 0),
#  datetime.datetime(2025, 3, 28, 0, 0),
#  datetime.datetime(2025, 4, 4, 0, 0),
#  datetime.datetime(2025, 4, 11, 0, 0),
#  datetime.datetime(2025, 4, 18, 0, 0),
#  datetime.datetime(2025, 4, 25, 0, 0),
#  datetime.datetime(2025, 5, 2, 0, 0),
#  datetime.datetime(2025, 5, 9, 0, 0),
#  datetime.datetime(2025, 5, 16, 0, 0),
#  datetime.datetime(2025, 5, 23, 0, 0),
#  datetime.datetime(2025, 5, 30, 0, 0),
#  datetime.datetime(2025, 6, 6, 0, 0),
#  datetime.datetime(2025, 6, 13, 0, 0),
# ...

# %%
list_df_spy_condor_info_mon_fri = []
for _dt_friday in fridays:
    # _dt_friday = fridays[-5]
    _dt_monday = _dt_friday - datetime.timedelta(4)
    _c1 = _df_spy_condor_info.index >= _dt_monday
    _c2 = _df_spy_condor_info.index <= _dt_friday
    list_df_spy_condor_info_mon_fri.append(_df_spy_condor_info[_c1 & _c2])
_df_spy_condor_info_monday_to_friday_2 = pd.concat(list_df_spy_condor_info_mon_fri)
_df_spy_condor_info_monday_to_friday_2
# Out:
# Ticker      underlying_price  annual_vol_col  deannualized_vol  strike_dist  \
# Date
# 2025-06-16        600.400024       19.780001           1.24614          7.5
# 2025-06-17        600.210022       20.530001           1.29339          8.0
# 2025-06-18        598.440002       20.900000           1.31670          8.0
# 2025-06-20        598.380005       20.740000           1.30662          8.0
# 2025-06-23        595.039978       21.150000           1.33245          8.0
# 2025-06-24        604.330017       18.190001           1.14597          7.0
# 2025-06-25        607.909973       17.280001           1.08864          6.5
# 2025-06-26        608.989990       16.670000           1.05021          6.5
# 2025-06-27        612.880005       16.309999           1.02753          6.5
# 2025-06-30        617.380005       17.190001           1.08297          6.5
# 2025-07-01        616.359985       16.980000           1.06974          6.5
# ...

# %%
list_dict_date_and_list_symbol_2 = [
    {'date':tup[0],'list_symbol':[tup[1]['sym_put_2'],tup[1]['sym_put_1'],tup[1]['sym_call_1'],tup[1]['sym_call_2']]}
    for tup in zip(
        _df_spy_condor_info_monday_to_friday_2.index,
        _df_spy_condor_info_monday_to_friday_2.to_dict('records')
    )
]

# %%
_df_spy_condor_info_monday_to_friday = _df_spy_condor_info[_c1 & _c2]
list_dict_date_and_list_symbol = [
    {'date':tup[0],'list_symbol':[tup[1]['sym_put_2'],tup[1]['sym_put_1'],tup[1]['sym_call_1'],tup[1]['sym_call_2']]}
    for tup in zip(
        _df_spy_condor_info_monday_to_friday.index,
        _df_spy_condor_info_monday_to_friday.to_dict('records')
    )
]

# %%
from polygon import RESTClient
# api_key = 'uSC5IgJZn8wLrWhH7Gviu5gcGmA3n55t'
api_key = open(f"temp_folder/polygon_api_key.txt",'r').read()
api_key = api_key.strip()
client = RESTClient(api_key=api_key)

# %%
import time 
def get_polygon_data(list_dict_date_and_list_symbol,num_days=1,adjusted="false",limit=120,time_delay=12):
    '''
    @param list_polygon_symbol: like ["O:SPY250725C00642000"]
    '''
    list_dict_all_dates = []
    for dict_date_and_list in list_dict_date_and_list_symbol:
        dt = dict_date_and_list['date']
        yyyy_mm_dd = f"{str(dt.year)}-{('0' + str(dt.month))[-2:]}-{('0' + str(dt.day))[-2:]}"
        list_symbol = dict_date_and_list['list_symbol']
        list_poly_symbol = ['O:' + sym for sym in list_symbol]
        list_dict_this_date_aggs = []
        for poly_symbol in list_poly_symbol:
            print(yyyy_mm_dd,poly_symbol,end=", ")
            aggs = []
            try:
                aggs = client.get_aggs(
                    poly_symbol,
                    num_days,
                    "day",
                    yyyy_mm_dd,
                    yyyy_mm_dd,
                    adjusted=adjusted,
                    sort="asc",
                    limit=limit,
                )
            except Exception as e:
                error_print(f"error on {yyyy_mm_dd} {poly_symbol} {str(e)}")
            list_dict_this_date_aggs.append({'symbol':poly_symbol,'list_this_date_aggs':aggs})
            time.sleep(time_delay)
        list_dict_all_dates.append({'yyyy-mm-dd':yyyy_mm_dd,'list_dict_this_date_aggs':list_dict_this_date_aggs})
        print(" ")
    return list_dict_all_dates

# %%
# list_dict_aggs = get_polygon_data(list_dict_date_and_list_symbol)
list_dict_aggs_2 = get_polygon_data(list_dict_date_and_list_symbol_2)
# Out:
# 2025-06-16 O:SPY250616P00585000, 2025-06-16 O:SPY250616P00592000, 2025-06-16 O:SPY250616C00608000, 2025-06-16 O:SPY250616C00615000,
# 2025-06-17 O:SPY250617P00584000, 2025-06-17 O:SPY250617P00592000, 2025-06-17 O:SPY250617C00608000, 2025-06-17 O:SPY250617C00616000,
# 2025-06-18 O:SPY250618P00582000, 2025-06-18 O:SPY250618P00590000, 2025-06-18 O:SPY250618C00606000, 2025-06-18 O:SPY250618C00614000,
# 2025-06-20 O:SPY250620P00582000, 2025-06-20 O:SPY250620P00590000, 2025-06-20 O:SPY250620C00606000, 2025-06-20 O:SPY250620C00614000,
# 2025-06-23 O:SPY250623P00579000, 2025-06-23 O:SPY250623P00587000, 2025-06-23 O:SPY250623C00603000, 2025-06-23 O:SPY250623C00611000,
# 2025-06-24 O:SPY250624P00590000, 2025-06-24 O:SPY250624P00597000, 2025-06-24 O:SPY250624C00611000, 2025-06-24 O:SPY250624C00618000,
# 2025-06-25 O:SPY250625P00595000, 2025-06-25 O:SPY250625P00602000, 2025-06-25 O:SPY250625C00614000, 2025-06-25 O:SPY250625C00621000,
# ...

# %%
# import pickle
# pickle.dump(list_dict_aggs_2,open('list_dict_aggs_2.pickle','wb'))

# %%
list_dict_history = []
for dict_aggs in list_dict_aggs_2:
    yyyy_mm_dd = dict_aggs['yyyy-mm-dd']
    _year = int(yyyy_mm_dd.replace('-','')[0:4])
    _month = int(yyyy_mm_dd.replace('-','')[4:6])
    _day = int(yyyy_mm_dd.replace('-','')[6:8])
    _dt = datetime.datetime(_year,_month,_day)
    dict_hist_row = {'date':_dt}
    opt_pseudos = ['put_2','put_1','call_1','call_2']
    for _idx,dict_this_date_aggs in enumerate(dict_aggs['list_dict_this_date_aggs']):
        opt_symbol = dict_this_date_aggs['symbol']
        key_opt_symbol = 'symbol_' + opt_pseudos[_idx]
        dict_hist_row[key_opt_symbol] = opt_symbol
        
        if dict_this_date_aggs is not None:
            for list_this_date_aggs  in dict_this_date_aggs['list_this_date_aggs']:
                # get open
                _open = list_this_date_aggs.open
                key_opt_open = 'open_' + opt_pseudos[_idx]
                dict_hist_row[key_opt_open] = _open
                
    # display_df_large_fields(dict_hist_row)
    list_dict_history.append(dict_hist_row)
                
df_opt_hist = pd.DataFrame(list_dict_history)
df_opt_hist.index = df_opt_hist['date']

df_opt_hist = df_opt_hist[[col for col in df_opt_hist.columns.values if 'date' not in col]]
df_opt_hist.index.name = 'Date'
# df_opt_hist.to_csv('df_opt_hist.csv',index=True)
df_opt_hist
# Out:
#                     symbol_put_2  open_put_2          symbol_put_1  \
# Date
# 2025-06-16  O:SPY250616P00585000        0.03  O:SPY250616P00592000
# 2025-06-17  O:SPY250617P00584000        0.02  O:SPY250617P00592000
# 2025-06-18  O:SPY250618P00582000        0.03  O:SPY250618P00590000
# 2025-06-20  O:SPY250620P00582000        0.03  O:SPY250620P00590000
# 2025-06-23  O:SPY250623P00579000        0.02  O:SPY250623P00587000
# 2025-06-24  O:SPY250624P00590000        0.04  O:SPY250624P00597000
# 2025-06-25  O:SPY250625P00595000        0.03  O:SPY250625P00602000
# 2025-06-26  O:SPY250626P00596000        0.02  O:SPY250626P00602000
# 2025-06-27  O:SPY250627P00600000        0.03  O:SPY250627P00606000
# 2025-06-30  O:SPY250630P00604000        0.02  O:SPY250630P00610000
# 2025-07-01  O:SPY250701P00603000        0.04  O:SPY250701P00610000
# 2025-07-02  O:SPY250702P00604000        0.02  O:SPY250702P00610000
# 2025-07-03  O:SPY250703P00609000        0.02  O:SPY250703P00616000
# ...

# %%
# df_opt_hist_short = df_opt_hist.copy()

# %%
_df_spy_condor_info_monday_to_friday.merge(
    df_opt_hist[['open_put_2','open_put_1','open_call_1','open_call_2']],
    left_index=True,right_index=True
)
# Out:
#             underlying_price  annual_vol_col  deannualized_vol  strike_dist  \
# Date
# 2025-07-21        628.770020       16.870001           1.06281          6.5
# 2025-07-22        629.099976       16.750000           1.05525          6.5
# 2025-07-23        631.549988       16.230000           1.02249          6.5
# 2025-07-24        634.599976       15.390000           0.96957          6.0
# 2025-07-25        635.090027       15.330000           0.96579          6.0
#
#             put_2  put_1  call_1  call_2           sym_put_2  \
# Date
# 2025-07-21  616.0  622.5   635.5   642.0  SPY250721P00616000
# 2025-07-22  616.0  622.5   635.5   642.0  SPY250722P00616000
# 2025-07-23  619.0  625.5   638.5   645.0  SPY250723P00619000
# 2025-07-24  623.0  629.0   641.0   647.0  SPY250724P00623000
# 2025-07-25  623.0  629.0   641.0   647.0  SPY250725P00623000
#
#                      sym_put_1          sym_call_1          sym_call_2  \
# Date
# ...

# %%
if __name__=='__main__':
    yopt = YahooOptions('SPY',days_of_hist=10)
    # display.display(yopt.expirations)
    # pdb.set_trace()
    df_opt_all_hist = yopt.get_options_all_strikes_in_hist(
        datetime.datetime(2025,8,22)
    )
    display.display(df_opt_all_hist.sort_values(['Date','strike'],axis=0))
    df_opt_all_hist_atm = yopt.select_atm_options_only(df_opt_all_hist)
    display.display(df_opt_all_hist_atm.sort_values(['Date','strike'],axis=0))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Price       adj_close  option  high   low  open  volume                 sym  \
# Date
# 2025-08-11       6.17    6.17  7.91  5.71  7.01    1769  SPY250822C00636000
# 2025-08-11       6.17    6.17  7.91  5.71  7.01    1769  SPY250822C00636000
# ...

# %%
display.display(df_opt_all_hist_atm.sort_values('Date',axis=0))
# Out:
# Price       adj_close  option  high   low  open  volume                 sym  \
# Date
# 2025-08-11       6.17    6.17  7.91  5.71  7.01    1769  SPY250822C00636000
# 2025-08-12       4.99    4.99  5.05  2.74  3.54    1364  SPY250822C00643000
# 2025-08-13       4.51    4.51  5.61  3.62  4.82       0  SPY250822C00645000
# 2025-08-14       4.10    4.10  4.95  3.45  3.54   14007  SPY250822C00645000
# 2025-08-15       4.31    4.31  6.08  4.06  6.08    5328  SPY250822C00643000
# 2025-08-18       3.71    3.71  4.24  3.28  3.77       0  SPY250822C00643000
# 2025-08-19       3.37    3.37  6.00  2.85  4.94   13562  SPY250822C00640000
# 2025-08-20       3.06    3.06  4.12  1.44  4.12   22540  SPY250822C00638000
# 2025-08-21       2.87    2.87  4.20  2.18  3.19   77357  SPY250822C00636000
#
# Price       underlying  strike pc expiry_date  rate        iv     afm_x  \
# Date
# 2025-08-11  635.919983     636  C  2025-08-22  0.04  0.141165  0.080017
# ...

# %%
yopt.df_und_hist.iloc[0].name.year
# Out:
# 2025

# %%
# _sym = df_opt_all_hist['sym']
# _dte = df_opt_all_hist['dte']
# _dtb = df_opt_all_hist['dtb']
# _df_opt = df_opt_all_hist['dfo']
df_opt_all_hist.iloc[0]
# Out:
# Price
# adj_close                     6.72
# option                        6.72
# high                          8.54
# low                           6.33
# open                          7.74
# volume                        1636
# sym             SPY250822C00635000
# underlying              635.919983
# strike                         635
# pc                               C
# expiry_date    2025-08-22 00:00:00
# rate                          0.04
# iv                        0.142185
# Name: 2025-08-11 00:00:00, dtype: object

# %%
# Out:
# Price       Adj Close  Close   High    Low   Open  Volume                 sym
# Date
# 2025-08-11       6.72   6.72   8.54   6.33   7.74    1636  SPY250822C00635000
# 2025-08-12      10.66  10.66  10.76   7.30   7.90     769  SPY250822C00635000
# 2025-08-13      12.25  12.25  13.32  10.50  12.62       0  SPY250822C00635000
# 2025-08-14      12.57  12.57  12.64  10.50  10.50     250  SPY250822C00635000
# 2025-08-15       9.96   9.96  12.43   9.85  12.43     491  SPY250822C00635000
# 2025-08-18       9.69   9.69  10.30   9.15   9.86     187  SPY250822C00635000
# 2025-08-19       6.83   6.83  10.08   6.03   9.41     520  SPY250822C00635000
# 2025-08-20       5.00   5.00   6.03   2.68   6.03   13620  SPY250822C00635000
# 2025-08-21       3.45   3.45   4.89   2.95   3.81   18507  SPY250822C00635000

# %%
dat = yf.Ticker("SPY")
dat.info
dat.calendar
dat.analyst_price_targets
dat.quarterly_income_stmt
dat.history(period='1mo')
dat.option_chain(dat.options[0]).calls
# Out:
# HTTP Error 404:
# HTTP Error 404:
#         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   SPY250821C00520000 2025-08-21 14:15:42+00:00   520.0     117.06  113.81
# 1   SPY250821C00540000 2025-08-15 17:24:57+00:00   540.0     104.18   94.11
# 2   SPY250821C00590000 2025-08-21 15:05:30+00:00   590.0      46.97   45.03
# 3   SPY250821C00595000 2025-08-20 19:21:10+00:00   595.0      43.44   39.98
# 4   SPY250821C00600000 2025-08-21 14:14:27+00:00   600.0      36.87   35.16
# ..                 ...                       ...     ...        ...     ...
# 64  SPY250821C00680000 2025-08-13 20:06:07+00:00   680.0       0.01     NaN
# 65  SPY250821C00685000 2025-08-14 17:42:37+00:00   685.0       0.01     NaN
# 66  SPY250821C00690000 2025-08-13 17:17:48+00:00   690.0       0.01     NaN
# 67  SPY250821C00695000 2025-08-20 20:06:08+00:00   695.0       0.01    0.00
# 68  SPY250821C00720000 2025-08-14 16:10:28+00:00   720.0       0.01     NaN
#
# ...

# %%
# !jupyter nbconvert --to script yahoo_options.ipynb

# %% [markdown]
# ### Test below if the is any kind of correlation between:
# 1. percent changes in the stock price with changes in implied vol
# 2. binary changes in the value `up_down` with changes in implied vol
# 3. changes in 1 and 2 with the previous day's change in implied vol (lagged)

# %%
df_opt_all_hist_atm['pct_chg_price'] = df_opt_all_hist_atm.underlying.pct_change()
df_opt_all_hist_atm['iv_chg'] = df_opt_all_hist_atm.iv.diff()
display.display(df_opt_all_hist_atm[['pct_chg_price','iv_chg']].corr())
df_opt_all_hist_atm['up_down'] = df_opt_all_hist_atm.pct_chg_price/df_opt_all_hist_atm.pct_chg_price.abs()
display.display(df_opt_all_hist_atm[['up_down','iv_chg']].corr())
df_opt_all_hist_atm['lag_iv_chg'] = df_opt_all_hist_atm.iv_chg.shift(1)
display.display(df_opt_all_hist_atm[['up_down','lag_iv_chg']].corr())
display.display(df_opt_all_hist_atm[['pct_chg_price','lag_iv_chg']].corr())

# %% [markdown]
# ### Below are methods that:
# 1. get the *current* values of stock options,
# 2. show the break-even values for a simple strategy which purchases a one day ATM Strangle

# %%
dte = datetime.datetime.now()
dtb = datetime.datetime(2024,5,20)
yf.download('^VIX',dtb,dte,auto_adjust=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price       Adj Close      Close       High    Low   Open Volume
# Ticker           ^VIX       ^VIX       ^VIX   ^VIX   ^VIX   ^VIX
# Date
# 2024-05-20  12.150000  12.150000  12.590000  12.07  12.27      0
# 2024-05-21  11.860000  11.860000  12.560000  11.84  12.30      0
# 2024-05-22  12.290000  12.290000  12.810000  11.78  12.05      0
# 2024-05-23  12.770000  12.770000  13.370000  11.52  11.53      0
# 2024-05-24  11.930000  11.930000  12.890000  11.89  12.86      0
# ...               ...        ...        ...    ...    ...    ...
# 2025-08-15  15.090000  15.090000  15.180000  14.40  14.43      0
# 2025-08-18  14.990000  14.990000  15.950000  14.95  15.73      0
# 2025-08-19  15.570000  15.570000  15.910000  14.76  15.23      0
# 2025-08-20  15.690000  15.690000  17.190001  15.57  15.95      0
# 2025-08-21  16.690001  16.690001  16.990000  15.65  15.72      0
#
# [315 rows x 6 columns]

# %%
def get_stock_hist(sym,dte=None,dtb=None):
    if dte is None:
        dte = datetime.datetime.now()
    if dtb is None:
        dtb = datetime.datetime(2022,5,20)

    df_stock = yf.download(sym,dtb,dte,auto_adjust=False)
    df_stock['pct_chg'] = df_stock.Close.pct_change()
    df_vix = yf.download('^VIX',dtb,dte,auto_adjust=False)
    df_vix = df_vix.rename(columns={'Close':'VIX'})
    df_stock = df_stock.merge(df_vix[['VIX']],left_index=True,right_index=True)
    df_stock = df_stock.iloc[1:]
    return df_stock

# %%
def get_options_chain(
    underlying_symbol,
    mid_strk,
    strike_range=20,
    expiry_string=None,    
):
    if expiry_string is None:
        dt = datetime.datetime.now() + datetime.timedelta(1)
        ymd = str(dt.year*100*100+dt.month*100+dt.day)
        expiry_string = f"{ymd[0:4]}-{ymd[4:6]}-{ymd[6:8]}"
        
    low_strk = mid_strk - int(strike_range/2)
    high_strk = mid_strk + int(strike_range/2)
    strikes = np.arange(low_strk,high_strk+1).tolist()
    ticker = yf.Ticker(underlying_symbol)
    # ticker_options_chain = ticker.option_chain(date=None)
    ticker_options_chain = ticker.option_chain(date=expiry_string)
    dfc = ticker_options_chain[0]
    dfc2 = dfc[dfc.strike.isin(strikes)].copy()
    dfc2['mid'] = (dfc2.ask+dfc2.bid)/2

    dfp = ticker_options_chain[1]
    dfp2 = dfp[dfp.strike.isin(strikes)].copy()
    dfp2['mid'] = (dfp2.ask+dfp2.bid)/2
    return dfc2,dfp2

# %%
def strangle_strat(df_stock,dfc2,dfp2,ms):
    ps = ms - 2
    cs = ms + 2
    put = float(str(dfp2[dfp2.strike==ps].mid.values[0]))
    call = float(str(dfc2[dfc2.strike==cs].mid.values[0]))
    
    # returns is a dict of strategy parameters
    returns = {
        'strikes':[ps,cs,ms],
        'put_call':[put,call],
        'put_call_sum':put+call,
        'break_even_pct':(put+call+ms-ps)/ms,
        'strangle_premium':(put+call)/((ps+cs)/2),
        'strike_percents':[(ps-ms)/ms,(cs-ms)/ms],
        'opt_price_percents':[put/ms,call/ms]

    }

    df_stk2 = df_stock.copy()
    # pl_calc = lambda pct_chg: max(
    #     -1*returns['strangle_premium'],
    #     abs(pct_chg) - returns['break_even_pct']
    # ) 
    def pl_calc(pct_chg): 
        if abs(pct_chg)<returns['break_even_pct']:
            return -1*returns['strangle_premium']
        else:
            return abs(pct_chg) - returns['break_even_pct']


    df_stk2['pl'] = df_stk2.pct_chg.apply(pl_calc)

    df_stk2['cum_pl'] = df_stk2.pl.cumsum()
#     df_stk2[['pct_chg','pl','cum_pl']] 
    return returns,df_stk2

# %%
def get_condor_price(
    atm_price,
    vix,
    vix1d,
    rate = 0.045,
    dte = 2/365,
    put_skew_per_leg = .03,
    call_skew_per_leg = .005
):
    # F = 617
    # K = F
    # t = 1/365
    # r = .045
    # strike_width = 7
    # mid_sigma = .1265
    F = atm_price
    K = F
    t = dte
    r = rate
    # calc strike width
    strike_width = round(F*vix/16,0)
    mid_sigma = vix1d

    
    call_inner_sigma = mid_sigma - call_skew_per_leg
    put_inner_sigma = mid_sigma + put_skew_per_leg
    call_inner_price = black.black('c', F, K+strike_width, t, r, call_inner_sigma)
    put_inner_price = black.black('p', F, K-strike_width, t, r, put_inner_sigma)
    strangle_inner = call_inner_price + put_inner_price
    
    call_outer_sigma = mid_sigma - call_skew_per_leg*2
    put_outer_sigma = mid_sigma + put_skew_per_leg*2
    try:
        call_outer_price = black.black('c', F, K+strike_width*2, t, r, call_outer_sigma)
        put_outer_price = black.black('p', F, K-strike_width*2, t, r, put_outer_sigma)
    except Exception as e:
        print(str(e))
        dict_error = {
            'F':F,'K':K,'strike_width':strike_width,'t':t,'r':r,
            'call_outer_sigma':call_outer_sigma,'put_outer_sigma':put_outer_sigma
        }
        error_print(dict_error)
        raise ValueError(str(e))
        
    strangle_outer = call_outer_price + put_outer_price
    
    iron_condor = strangle_inner-strangle_outer
    
    dict_ret = {
        'put_inner_price':float(put_inner_price),
        'call_inner_price':float(call_inner_price),
        'strangle_inner':float(strangle_inner),
        'call_outer_price':float(call_outer_price),
        'put_outer_price':float(put_outer_price),
        'strangle_outer':float(strangle_outer),
        'iron_condor':float(iron_condor)
    }
    
    return dict_ret

# %%
def condor_strat():
    dte = datetime.datetime.now()
    dtb = dte - datetime.timedelta(2*365)
    df_sym_list_hist = get_stock_list_hist(['SPY','^VIX','^VIX1D'],dte,dtb,return_all_cols=True)
    # get ms mid_strike
    df_sym_list_hist['ms'] = [round(v,0) for v in df_sym_list_hist['Open_SPY'].values]
    # get daily call and put strikes
    df_sym_list_hist['vol1d_to_use'] = [v/16 for v in df_sym_list_hist['Open_^VIX'].values]
    df_sym_list_hist['strike_width'] = [round(row.ms*row.vol1d_to_use,0) for row in df_sym_list_hist]
    # condor inside strikes
    df_sym_list_hist['condor_cs_1'] = df_sym_list_hist.ms + df_sym_list_hist.strike_width
    df_sym_list_hist['condor_ps_1'] = df_sym_list_hist.ms - df_sym_list_hist.strike_width
    # condor outside strikes
    df_sym_list_hist['condor_cs_2'] = df_sym_list_hist.condor_cs_1 + df_sym_list_hist.strike_width
    df_sym_list_hist['condor_ps_2'] = df_sym_list_hist.condor_ps_1 - df_sym_list_hist.strike_width
    return df_sym_list_hist
#     ps = ms - 2
#     cs = ms + 2
#     put = float(str(dfp2[dfp2.strike==ps].mid.values[0]))
#     call = float(str(dfc2[dfc2.strike==cs].mid.values[0]))
    
#     # returns is a dict of strategy parameters
#     returns = {
#         'strikes':[ps,cs,ms],
#         'put_call':[put,call],
#         'put_call_sum':put+call,
#         'break_even_pct':(put+call+ms-ps)/ms,
#         'strangle_premium':(put+call)/((ps+cs)/2),
#         'strike_percents':[(ps-ms)/ms,(cs-ms)/ms],
#         'opt_price_percents':[put/ms,call/ms]

#     }

#     df_stk2 = df_stock.copy()
#     # pl_calc = lambda pct_chg: max(
#     #     -1*returns['strangle_premium'],
#     #     abs(pct_chg) - returns['break_even_pct']
#     # ) 
#     def pl_calc(pct_chg): 
#         if abs(pct_chg)<returns['break_even_pct']:
#             return -1*returns['strangle_premium']
#         else:
#             return abs(pct_chg) - returns['break_even_pct']


#     df_stk2['pl'] = df_stk2.pct_chg.apply(pl_calc)

#     df_stk2['cum_pl'] = df_stk2.pl.cumsum()

#     return returns,df_stk2

# %%
def plot_strat(df_stk2):
    df_stk3 = df_stk2.copy()
    df_stk3['yyyymmdd'] = [
        d.year*100*100+d.month*100+d.day
        for d in df_stk3.index.to_pydatetime()
    ]

    df_stk3['yyyymmdd'] = [
        d[0:4] + '-' + d[4:6] + '-' + d[6:8]
        for d in df_stk3.yyyymmdd.astype(str).values
    ]

    x_value_labels = [
        f"{d.year}-{('0'+str(d.month))[0:2]}-{('0'+str(d.day))[0:2]}"
        for d in df_stk3.index.to_pydatetime()
    ]

    df_stk3.index = list(range(len(df_stk3)))
    bdate = df_stk3.yyyymmdd.values[0]
    edate = df_stk3.yyyymmdd.values[-1]
    fig = pu.plotly_plot(
        df_stk3[['yyyymmdd','cum_pl']],
        'yyyymmdd',
        plot_title=f"Long Daily Strangle Strategy from {bdate} to {edate}"
    )
    return fig

# %%
def get_stock_list_hist(sym_list,dte=None,dtb=None,return_all_cols=False):
    if return_all_cols:
        df_all = None
        first_sym = 0
    else:
        df_all = get_stock_hist(sym_list[0],dte=dte,dtb=dtb)
        df_all = df_all[['Close']].rename(columns={'Close':sym_list[0]}).copy()
        first_sym = 1
    if len(sym_list)<2:
        return df_all
    for s in sym_list[first_sym:]:
        df_temp = get_stock_hist(s,dte=dte,dtb=dtb)
        if return_all_cols:
            dict_rename = {}
            df_temp.columns = df_temp.columns.get_level_values(0)
            for c in df_temp.columns.values:
                dict_rename[c] = c + "_" + s
            df_temp = df_temp.rename(columns=dict_rename)
        else:
            df_temp = df_temp[['Close']].rename(columns={'Close':s}).copy()
        if df_all is None:
            df_all = df_temp.copy()
        else:
            df_all = df_all.merge(df_temp,how='left',left_index=True,right_index=True)
    return df_all

# %%
dte = datetime.datetime.now()
dtb = dte - datetime.timedelta(2*365)
df_sym_list_hist_beg = get_stock_list_hist(['SPY','^VIX','^VIX1D'],dte,dtb,return_all_cols=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
def display_df_large_numbers(df,rounding=5,g_size=10):
    '''
    Display a dataframe without truncating number field types
    '''
    with pd.option_context('display.float_format',lambda x: f'%.{g_size}g' % x):
        display.display(df)

def is_number(s):
    try:
        poss_num = str_to_number(s)
        float(str(poss_num))
        return True
    except:
        return False

def str_to_number(value):
    if value is None:
        return None
    perc_divisor = 1
    pos_neg = 1
    s = str(value).strip().replace(' ','')
    s = s.replace('$','').replace(',','')
    if "(" in s:
        pos_neg = -1
    if '%' in s:
        perc_divisor =100
        s = s.replace('%','')
    s = s.replace('(','').replace(')','')
    try:
        float(s)
    except:
        v = str(value)
        v = v.replace('*','').strip()
        return v
    try:
        if ('.' in s) or (perc_divisor>1):
            return float(s.strip()) * pos_neg / perc_divisor
        return int(s.strip()) * pos_neg
    except:
        return str(value).replace(' **','')

def str_to_num_nan_is_0(s):
    if str(s).lower() == 'nan':
        return 0
    if str(s).lower() == '-':
        return 0
    
    return str_to_number(s)

# %%
df_sym_list_hist = df_sym_list_hist_beg.copy()
# get ms mid_strike
df_sym_list_hist['ms'] = [round(v,0) for v in df_sym_list_hist['Open_SPY'].values]
# get vol to use for strike width, and the strike width
df_sym_list_hist['vol1d_to_use'] = [v*.01 for v in df_sym_list_hist['Open_^VIX'].values]
# df_sym_list_hist['strike_width'] = [round(row['ms']*row['vol1d_to_use']/16,0) for row in df_sym_list_hist.to_dict(orient='records')]
df_sym_list_hist['strike_width'] = [int(row['ms']*row['vol1d_to_use']/16) for row in df_sym_list_hist.to_dict(orient='records')]
# condor inside strikes
df_sym_list_hist['condor_cs_1'] = df_sym_list_hist.ms + df_sym_list_hist.strike_width
df_sym_list_hist['condor_ps_1'] = df_sym_list_hist.ms - df_sym_list_hist.strike_width
# condor outside strikes
df_sym_list_hist['condor_cs_2'] = df_sym_list_hist.condor_cs_1 + df_sym_list_hist.strike_width
df_sym_list_hist['condor_ps_2'] = df_sym_list_hist.condor_ps_1 - df_sym_list_hist.strike_width
df_sym_list_hist['condor_info'] = [
    get_condor_price(row['ms'],row['Open_^VIX']/100,row['Open_^VIX1D']/100)['iron_condor']
    for row in df_sym_list_hist.to_dict(orient="records")
]
df_sym_list_hist['vix_to_vix1d_ratio'] = df_sym_list_hist['Open_^VIX']/df_sym_list_hist['Open_^VIX1D']
# get condor premium using ^Open_^VIX1D vol value, an approximate put and call skew, and the black scholes model
# get vix1d mid strike vol

# %%
display_df_large_numbers(df_sym_list_hist.iloc[-1],rounding=2,g_size=4)
# Out:
# Price
# Adj Close_SPY            634.9
# Close_SPY                634.9
# High_SPY                   638
# Low_SPY                  634.3
# Open_SPY                 636.3
# Volume_SPY           2.612e+07
# pct_chg_SPY          -0.005077
# VIX_SPY                   16.7
# Adj Close_^VIX            16.7
# Close_^VIX                16.7
# High_^VIX                16.99
# Low_^VIX                 15.65
# Open_^VIX                15.72
# Volume_^VIX                  0
# pct_chg_^VIX           0.06437
# VIX_^VIX                  16.7
# Adj Close_^VIX1D         14.75
# Close_^VIX1D             14.75
# High_^VIX1D              14.82
# Low_^VIX1D               10.21
# Open_^VIX1D              10.31
# Volume_^VIX1D                0
# pct_chg_^VIX1D          0.3532
# VIX_^VIX1D                16.7
# ms                         636
# vol1d_to_use            0.1572
# strike_width                 6
# condor_cs_1                642
# condor_ps_1                630
# condor_cs_2                648
# ...

# %%
_c1 = df_sym_list_hist.index>=datetime.datetime(2024,3,1)
_c2 = df_sym_list_hist.index<=datetime.datetime(2025,5,1)
df_sym_list_hist[_c1 & _c2].plot(y='vix_to_vix1d_ratio',figsize=(10, 7))
# Out:
# <Axes: xlabel='Date'>

# %%
display.display(
    df_sym_list_hist[[
        'Open_SPY','Open_^VIX','Open_^VIX1D','ms','condor_info',
        # 'vol1d_to_use','strike_width','condor_cs_1','condor_ps_1','condor_cs_2','condor_ps_2'
    ]]
)
# Out:
# Price         Open_SPY  Open_^VIX  Open_^VIX1D     ms  condor_info
# Date
# 2023-08-23  439.250000  16.639999        10.18  439.0     0.274437
# 2023-08-24  444.690002  15.570000        10.47  445.0     0.451895
# 2023-08-25  438.679993  17.209999        15.21  439.0     0.776165
# 2023-08-28  442.239990  16.240000         9.82  442.0     0.380626
# 2023-08-29  442.649994  15.080000         9.79  443.0     0.379842
# ...                ...        ...          ...    ...          ...
# 2025-08-15  645.989990  14.430000         8.45  646.0     0.357889
# 2025-08-18  642.859985  15.730000         7.36  643.0     0.237560
# 2025-08-19  643.119995  15.230000         6.34  643.0     0.152639
# 2025-08-20  639.400024  15.950000         8.08  639.0     0.305369
# 2025-08-21  636.280029  15.720000        10.31  636.0     0.581716
#
# [501 rows x 5 columns]

# %%
df_sym_list_hist.tail(4)[['ms','Open_SPY','Open_^VIX','Open_^VIX1D']]
# Out:
# Price          ms    Open_SPY  Open_^VIX  Open_^VIX1D
# Date
# 2025-08-18  643.0  642.859985      15.73         7.36
# 2025-08-19  643.0  643.119995      15.23         6.34
# 2025-08-20  639.0  639.400024      15.95         8.08
# 2025-08-21  636.0  636.280029      15.72        10.31

# %%
get_condor_price(617,.16,.14,dte=1.5/365),get_condor_price(583,.21,.21,dte=1.5/365)
# Out:
# ({'put_inner_price': 0.6759818160496464,
#   'call_inner_price': 0.35504291118101966,
#   'strangle_inner': 1.031024727230666,
#   'call_outer_price': 0.018384289968822302,
#   'put_outer_price': 0.2133523978518251,
#   'strangle_outer': 0.2317366878206474,
#   'iron_condor': 0.7992880394100187},
#  {'put_inner_price': 0.8976316961274181,
#   'call_inner_price': 0.5984834173415104,
#   'strangle_inner': 1.4961151134689286,
#   'call_outer_price': 0.0474390762890639,
#   'put_outer_price': 0.22705356767246226,
#   'strangle_outer': 0.2744926439615262,
#   'iron_condor': 1.2216224695074023})

# %% [markdown]
# ### Use the methods above to show values for the one day strangle on SPY

# %%
20/300
# Out:
# 0.06666666666666667

# %%
import matplotlib.pyplot as plt

# %%
def condor_pl(row):
    close = row.Close_SPY
    condor_price = row.condor_info
    diff_spy = row.Close_SPY - row.Open_SPY

    pl_call_1 = max(row.Close_SPY - row.condor_cs_1,0)
    pl_call_2 = max(row.Close_SPY - row.condor_cs_2,0)
    pl_cs = pl_call_1 - pl_call_2

    pl_put_1 = max(row.condor_ps_1 - row.Close_SPY,0)
    pl_put_2 = max(row.condor_ps_2 - row.Close_SPY,0)
    pl_ps = pl_put_1 - pl_put_2

    pl_strat = -1 * (pl_cs + pl_ps) + condor_price
    return round(pl_strat,4)

df_sym_list_hist2 = df_sym_list_hist.copy()
_c1 = df_sym_list_hist2.index>=datetime.datetime(2023,3,1)
_c2 = df_sym_list_hist2.index<=datetime.datetime(2025,9,1)
df_sym_list_hist2 = df_sym_list_hist2[_c1 & _c2].copy()
df_sym_list_hist2['strat_pl']  = df_sym_list_hist2.apply(condor_pl,axis=1)
df_sym_list_hist2['cumulative_pl'] = df_sym_list_hist2.strat_pl.cumsum()

initial_investment = 300
df_sym_list_hist2['strat_perc']  = df_sym_list_hist2.strat_pl / initial_investment
df_sym_list_hist2['cumulative_perc'] = (1 + df_sym_list_hist2.strat_perc).cumprod()

plot_cols = [
    'ms','strike_width','condor_info','Close_SPY','Open_^VIX','Open_^VIX1D',
    'strat_pl','condor_cs_1','condor_cs_2','condor_ps_1','condor_ps_2'
]
# _c1 = df_sym_list_hist2.strat_pl < -8
# display_df_large_numbers(df_sym_list_hist2[_c1][plot_cols].iloc[0],rounding=2,g_size=4)

strat_sum = round(df_sym_list_hist2.strat_pl.sum(),2)
days = len(df_sym_list_hist2)
avg_condor_prem = df_sym_list_hist2.condor_info.mean()
print(
    {'strat pl':strat_sum,'days':days,'daily pl': strat_sum/days,'avg_condor_prem':avg_condor_prem}
)

ax1 = df_sym_list_hist2.plot(y='cumulative_pl',figsize=(10, 7))
ax1.grid(which='major',linestyle='--', linewidth=0.7, color='gray')
plt.show()

ax2 = df_sym_list_hist2.plot(y='cumulative_perc',figsize=(10, 7))
ax2.grid(which='major',linestyle='--', linewidth=0.7, color='gray')
plt.show()
# Out:
# {'strat pl': np.float64(134.91), 'days': 501, 'daily pl': np.float64(0.2692814371257485), 'avg_condor_prem': np.float64(0.5533581407467595)}

# %%
def one_day_strangle():
    # pdb.set_trace()
    mid_strike = None#396
    # specify expiration string
    expiry_string =  None#'2023-03-24'
    
    # specify stock
    df_stock = get_stock_hist('SPY')
    
    # get close
    stock_close = df_stock.iloc[-1].Close.values[0]
    
    # get mid_strike
    if mid_strike is None:
        mid_strike = round(stock_close,0) if mid_strike is None else mid_strike
    
    # get expiry_string
    if expiry_string is None:
        n = datetime.datetime.now()
        wd = n.weekday()
        if wd>4:
            days_to_add = 7-wd
            n = n + datetime.timedelta(days_to_add)
        yyyymmdd = str(n.year*100*100 + n.month*100 + n.day)    
        expiry_string = yyyymmdd[0:4] + '-' + yyyymmdd[4:6] + '-' + yyyymmdd[6:8]
    
    # get calls and puts  
    df_calls,df_puts = get_options_chain('SPY',mid_strike,expiry_string=expiry_string)
    
    # display results
    expiry = df_calls.contractSymbol.iloc[0][:-9][-6:]
    display.display(f"stock_price = {stock_close}, mid strike = {mid_strike}, expiry: {expiry}")
    df_calls_and_puts = df_calls[['strike','mid']].merge(
        df_puts[['strike','mid']],how='left',on='strike'
    )
    df_calls_and_puts = df_calls_and_puts.rename(columns={'mid_x':'call','mid_y':'put'})
    display.display(df_calls_and_puts)
    strat_params,df_strat_results = strangle_strat(df_stock,df_calls,df_puts,mid_strike)
    display.display(strat_params)
    return {
        'stock_close':stock_close,
        'mid_strike':mid_strike,
        'expiry_string':expiry_string,
        'df_stock':df_stock,
        'df_calls':df_calls,
        'df_puts':df_puts,
        'df_calls_and_puts':df_calls_and_puts,
        'strat_params':strat_params,
        'df_strat_results':df_strat_results,
        
    }

# %%
dict_ods = one_day_strangle()

# %%
display.display(dict_ods['df_calls'])

# %%
display.display(dict_ods['df_puts'])

# %%
pvol.implied_volatility(1.51,621.13-.68,621,.045,1.5/365,'c')
# pvol.implied_volatility?

# %%
_df_strat_results = dict_ods['df_strat_results']
_dtb = datetime.datetime(2025,1,1)
_dte = datetime.datetime.now()
_df_vix = yf.download('^VIX',_dtb,dte,auto_adjust=False)
_df_vix = _df_vix.rename(columns={'Close':'VIX'})
_df_vix1d = yf.download('^VIX1D',_dtb,dte,auto_adjust=False)
_df_vix1d = _df_vix1d.rename(columns={'Close':'VIX1D'})
df_vix_both = _df_vix['VIX'].merge(_df_vix1d['VIX1D'],left_index=True,right_index=True)
_c1 = _df_strat_results.index > _dtb
_df_strat_results = _df_strat_results[_c1]
# _df_strat_results = _df_strat_results.merge(_df_vix1d['VIX1D'],left_index=True,right_index=True)
# display.display(_df_strat_results)
# df_vix_both.columns = df_vix_both.columns.get_level_values(0)
df_vix_both = df_vix_both.reset_index()
df_vix_both['diff'] = df_vix_both['^VIX'] -  df_vix_both['^VIX1D']
display.display(df_vix_both.columns.values)
df_vix_both.to_csv('df_vix_30D_1D.csv',index=True)

# %%
# _df_strat_results = _df_strat_results.reset_index()
# _df_strat_results.columns = [tup[0] + ('_' + tup[1]) if len(tup[1])>0 else '' for tup in _df_strat_results.columns.values]
_df_strat_results.columns = [c[0] for c in _df_strat_results]
_df_strat_results
df_vix_both

# %%
calc_implied_vol?

# %%
calc_implied_vol(616,2.415,616.28,1.5/365,0.045,'c')

# %%
.25 + .15

# %%
dict_ods['df_calls_and_puts']

# %% [markdown]
# ### Show correlations between VIX values and SPY changes

# %%
df_spy_vix = get_stock_list_hist(['SPY','^VIX','VIY00'])

# %%
df_spy_vix['spy_pct_chg'] = df_spy_vix.SPY.pct_change()
df_spy_vix = df_spy_vix.iloc[1:]
df_spy_vix['vix_chg'] = df_spy_vix['^VIX'] - df_spy_vix['^VIX'].shift(1)
df_spy_vix[['spy_pct_chg','vix_chg']].copy().corr()

# %% [markdown]
# ### Show the distribution of stock percent changes over the period covered by the dataframe `df_stock`

# %%
df_stock.pct_chg.hist(bins=20)

# %% [markdown]
# ### use csv files extracted from the CME's FTP site to show the results of the strangle strategy above, but using the *ES* contracts on the CME, rather than the options on the *SPY*

# %%
yyyymmdd_of_zip = 20230410
filename = f"cme.settle.{yyyymmdd_of_zip}.s.csv.zip"

# %%
# Login to the FTP site
ftp = ftplib.FTP("ftp.cmegroup.com")
ftp.login()

# Change directory to the desired location
ftp.cwd("/pub/settle")

# Download the gzip file
dest_dir = 'temp_folder'
full_filename = f'{dest_dir}/{filename}'
with open(full_filename, "wb") as f:
    ftp.retrbinary("RETR " + filename, f.write)

ftp.quit()
    
# Define the input and output file names
input_file = full_filename
output_folder = dest_dir

# Create a ZipFile object for the input file
with zipfile.ZipFile(input_file, "r") as zip_ref:
    # Extract all contents of the input file to the output folder
    zip_ref.extractall(output_folder)

# Print a message indicating the file has been unzipped
print(f"{input_file} has been unzipped to {output_folder}.")

# %%
def round_to_n(v,n):
    b = round(v/n,0)
    l = b*n
    h = (b+1)*n
    return l if (v - l) < (h - v) else h

# %%
yyyymmdd = 20230410
expiry_str = None
symbol_regex = None#'^E[12345]'
if symbol_regex is None:
    symbol_regex = '^E[12345]'
yyyy = str(yyyymmdd)[0:4]
mm = str(yyyymmdd)[4:6]
dd = str(yyyymmdd)[6:8]
if expiry_str is None:
    expiry_str = f'{yyyy}-{mm}-{dd}'
f = f'temp_folder/cme.settle.{yyyymmdd}.s.csv'
df_cme = pd.read_csv(f)

# get options
c1 = df_cme.Sym.str.contains(symbol_regex)
c2 = df_cme.MatDt > expiry_str
c3 = df_cme.SecTyp=='OOF'
c_all = c1 & c2 & c3
df_cme_options = df_cme[c_all].copy()

mat_dt = df_cme_options.MatDt.min()
c2 = df_cme.MatDt==mat_dt
c3 = df_cme.SecTyp=='OOF'
c_all = c1 & c2 & c3
df_cme_options = df_cme[c_all].copy()
display.display(df_cme_options[['MatDt','Sym']].drop_duplicates().sort_values(['MatDt','Sym']))
c1 = df_cme.Sym==df_cme_options.iloc[0]['UndlyID']
c3 = df_cme.SecTyp==df_cme_options.iloc[0]['UndlySecTyp']
c4 = df_cme.MMY == df_cme_options.iloc[0]['UndlyMMY']
c_all = c1 & c3 & c4

df_under = df_cme[c_all].copy()
future = df_under.iloc[0].SettlePrice
c3 = df_cme_options.SecTyp=='OOF'
c4 = df_cme_options.PutCall==0
c5 = df_cme_options.StrkPx <= future
c6 = df_cme_options.StrkPx >= future*.9
c_all = c3 & c4 & c5 & c6
cols = ['BizDt','StrkPx','PutCall','FixingPrice','SettlePrice','MatDt']
df_cme_puts = df_cme_options[c_all][cols]
c3 = df_cme_options.SecTyp=='OOF'
c4 = df_cme_options.PutCall==1
c5 = df_cme_options.StrkPx >= future
c6 = df_cme_options.StrkPx <= future*1.1
c_all = c3 & c4 & c5 & c6
df_cme_calls = df_cme_options[c_all][cols]

display.display(df_under[cols])
display.display(df_cme_puts[-5:])
display.display(df_cme_calls[:5])

# calculate break even percent
m = round_to_n(round(future),5)
put_price = df_cme_puts[df_cme_puts.StrkPx == (m-20)].iloc[0].SettlePrice
call_price = df_cme_calls[df_cme_calls.StrkPx == (m+20)].iloc[0].SettlePrice
be = (put_price + call_price + 20)/m
display.display(f"break even percent = {be}")
