# %% [markdown]
# ## yahoo_options
# The yahoo_options notebook gives examples for usying the yfinance package to access historical data for options of stocks, as wells as their underlyings.

# %%
import yfinance as yf
import datetime
import pandas as pd
import numpy as np
from lxml import html
import requests
import py_vollib.black.implied_volatility as pvol
import py_vollib.black as black
import pdb
from IPython import display
import plotly_utilities as pu

import ftplib
import zipfile
import os
import curl_cffi

# %%
def display_df_large_fields(df,col_size=50):
    '''
    Display a dataframe without truncating number field types
    '''
    with pd.option_context('display.max_colwidth',col_size):
        display.display(df)

# %%
def get_yyyymmdd(td):
    tds = str(td)[0:10]
    tds = tds.replace('-','')
    return int(tds)

def get_pc(sym):
    l = len(sym) - 15 
    return sym[l+6]

def get_implied_price(df_options,use_mid=True):
    strikes = [
        s for s in df_options.strike.unique()
        if len(df_options[df_options.strike==s])==2
    ]
    min_strike = min(strikes)
    c1 = df_options.strike==min_strike
    c2 = df_options.pc == 'C'
    df_min_strike_call = df_options[c1 & c2]
    c2 = df_options.pc == 'P'
    df_min_strike_put = df_options[c1 & c2]
    if use_mid:
        call_mid = (df_min_strike_call.bid.values[0] + df_min_strike_call.ask.values[0])/2
        put_mid = (df_min_strike_put.bid.values[0] + df_min_strike_put.ask.values[0])/2    
        underlying = call_mid + min_strike - put_mid
    else:
        call_last = df_min_strike_call.lastPrice.values[0]
        put_last = df_min_strike_put.lastPrice.values[0]
        underlying = call_last + min_strike - put_last
    return underlying

def calc_implied_vol(strike,opt_price,und_price,dte_perc_of_year,rate,pc):
    try:
        iv = pvol.implied_volatility(opt_price,und_price,strike,rate,dte_perc_of_year,pc)
    except Exception as e:
        print(f"Exception: {row}")
        return None
    return iv
    
def implied_vol(row):
    opt_price = row.option
    und_price = row.underlying
    row_date = datetime.datetime(
        row.name.year,row.name.month,row.name.day)
    dte = row.expiry_date - row_date
    dte = dte.days/365
    rate = row.rate
    pc = row.pc.lower()
    strike = row.strike
    try:
        iv = pvol.implied_volatility(opt_price,und_price,strike,rate,dte,pc)
    except Exception as e:
        print(f"Exception: {row}")
        return None
    return iv

def exp_string_to_datetime(exp_string):
    return datetime.datetime(
        int(exp_string[0:2])+2000,
        int(exp_string[2:4]),
        int(exp_string[4:6])
    )

def exp_datetime_to_exp_string(exp_dt):
    year = exp_dt.year
    month = exp_dt.month
    day = exp_dt.day
    yyyymmdd = year*100*100 + month*100 + day
    return str(yyyymmdd)[-6:]

class YahooOptions:
    def __init__(self,symbol,dte=None,days_of_hist=100,round_to=0):
        self.symbol = symbol
        session = curl_cffi.requests.Session(impersonate="chrome")
        self.ticker = yf.Ticker(symbol, session=session)
        self.ticker_options_chain = self.ticker.option_chain(date=None)
        self.expirations = self.ticker._expirations
        self.dte = datetime.datetime.now() if dte is None else dte
        self.dtb = self.dte - datetime.timedelta(days_of_hist)
        self.df_und_hist = yf.download(symbol,self.dtb,self.dte)
        self.prev_close = self.df_und_hist.iloc[-1].Close
        
    def get_options(self,exp_date_string):
        expirations = list(self.expirations.keys())
        if exp_date_string not in expirations:
            raise(ValueError(f"expiry {exp_date_string} not in {expirations} "))
        symbol = self.symbol
        ticker = self.ticker
        ticker_options_chain = ticker.option_chain(date=exp_date_string)
        df_ticker_options = pd.DataFrame()
        for df in ticker_options_chain:
            df_ticker_options = pd.concat([df_ticker_options,df])

        df_ticker_options['pc'] = df_ticker_options.contractSymbol.apply(get_pc)
        df_ticker_options['td_yyyymmdd'] = df_ticker_options.lastTradeDate.apply(get_yyyymmdd)
        return df_ticker_options
    
    

    def get_options_all_strikes_in_hist(
        self,expiry_datetime,strikes_to_get=None,pc='C',rounding=0,
        extended_strike_range_perc = 0.05
    ):
        exp_date_string = exp_datetime_to_exp_string(expiry_datetime)
        df_all_op = pd.DataFrame()
        dte = self.dte
        dtb = self.dtb
        strikes_to_fetch = strikes_to_get
        if strikes_to_fetch is None:
            strikes_to_fetch = sorted(
                [
                    int(v.round(rounding))
                    for v in self.df_und_hist.Close.values
                ]
            )
            
        dfu = self.df_und_hist
        for strike in strikes_to_fetch:
            s = f'00000000{str(int(int(strike)*1000))}'[-8:]
            sym = f'{self.symbol}{exp_date_string}{pc}{s}'
            dfo = yf.download(sym,dtb,dte)
            dfb = dfo.rename(columns={'Close':'option'}).merge(
                dfu[['Close']].rename(columns={'Close':'underlying'}),on='Date')
            dfb['strike'] = strike
            dfb['pc'] = pc
            dfb['expiry_date'] = expiry_datetime
            dfb['rate'] = .04
            df_all_op = pd.concat([df_all_op,dfb])    
        
        df_all_op['iv'] = df_all_op.apply(implied_vol,axis=1)
        df_all_op = df_all_op.rename(
            columns = {
                c:c.lower().replace(' ','_') 
                for c in df_all_op.columns.values
            }
        )
        return df_all_op

    def select_atm_options_only(self,df_all_op):
        '''
        @param df_all_op: The DataFrame that the method get_options_all_strikes_in_hist
                            returns
        '''
        df_all_op['afm'] = df_all_op.strike - df_all_op.underlying
        df_all_op['afm'] = df_all_op['afm'].abs()
        df_all_op_gb = df_all_op[
            ['afm']
        ].groupby(
            by=[df_all_op.index],
        ).min()
        
        df_opt_all_2 = df_all_op.merge(
            df_all_op_gb,left_index=True,right_index=True,how='left'
        )
        df_opt_all_2 =  df_opt_all_2[df_opt_all_2.afm_x==df_opt_all_2.afm_y]
        df_opt_all_2 = df_opt_all_2.drop_duplicates()
        return df_opt_all_2

# %%
if __name__=='__main__':
    yopt = YahooOptions('SPY')
    display.display(yopt.expirations)
    df_opt_all_hist = yopt.get_options_all_strikes_in_hist(
        datetime.datetime(2025,3,21)
    )
    display.display(df_opt_all_hist)
    df_opt_all_hist_atm = yopt.select_atm_options_only(df_opt_all_hist)
    display.display(df_opt_all_hist_atm)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# {'2025-06-30': 1751241600,
#  '2025-07-01': 1751328000,
#  '2025-07-02': 1751414400,
#  '2025-07-03': 1751500800,
#  '2025-07-07': 1751846400,
#  '2025-07-08': 1751932800,
#  '2025-07-09': 1752019200,
#  '2025-07-10': 1752105600,
#  '2025-07-11': 1752192000,
#  '2025-07-18': 1752796800,
#  '2025-07-25': 1753401600,
#  '2025-07-31': 1753920000,
#  '2025-08-01': 1754006400,
#  '2025-08-08': 1754611200,
#  '2025-08-15': 1755216000,
#  '2025-08-29': 1756425600,
#  '2025-09-19': 1758240000,
#  '2025-09-30': 1759190400,
#  '2025-10-17': 1760659200,
#  '2025-10-31': 1761868800,
#  '2025-11-21': 1763683200,
#  '2025-11-28': 1764288000,
#  '2025-12-19': 1766102400,
#  '2025-12-31': 1767139200,
#  '2026-01-16': 1768521600,
#  '2026-03-20': 1773964800,
#  '2026-03-31': 1774915200,
#  '2026-06-18': 1781740800,
#  '2026-09-18': 1789689600,
#  '2026-12-18': 1797552000,
#  '2027-01-15': 1799971200,
#  '2027-12-17': 1829001600}
# /var/folders/6c/341v5lbj2ms1zvq3z7p4df5r0000gn/T/ipykernel_39620/3906358944.py:103: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00495000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00503000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00504000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00512000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00523000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00524000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00525000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00526000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00532000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00534000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00535000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00536000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00538000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00545000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00547000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00549000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00549000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00553000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00553000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00554000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00557000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00557000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00558000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00559000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00559000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00562000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00563000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00563000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00563000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00565000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00565000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00567000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00572000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00574000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00577000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00581000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00581000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00581000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00585000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00586000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00586000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00588000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00588000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00589000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00589000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00591000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00591000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00591000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00592000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00593000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00594000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00594000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00594000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00595000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00596000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00596000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00597000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00598000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00600000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00600000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00601000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00601000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00602000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00607000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00607000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00612000']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY250321C00615000']: YFTzMissingError('possibly delisted; no timezone found')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 yopt = YahooOptions('SPY')
#       3 display.display(yopt.expirations)
# ----> 4 df_opt_all_hist = yopt.get_options_all_strikes_in_hist(
#       5     datetime.datetime(2025,3,21)
#       6 )
#       7 display.display(df_opt_all_hist)
#       8 df_opt_all_hist_atm = yopt.select_atm_options_only(df_opt_all_hist)
#
# Cell In[5], line 112, in YahooOptions.get_options_all_strikes_in_hist(self, expiry_datetime, strikes_to_get, pc, rounding, extended_strike_range_perc)
#     110 s = f'00000000{str(int(int(strike)*1000))}'[-8:]
#     111 sym = f'{self.symbol}{exp_date_string}{pc}{s}'
# --> 112 dfo = yf.download(sym,dtb,dte)
#     113 dfb = dfo.rename(columns={'Close':'option'}).merge(
#     114     dfu[['Close']].rename(columns={'Close':'underlying'}),on='Date')
#     115 dfb['strike'] = strike
#
# File ~/Virtualenvs3/risktables/lib/python3.9/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~/Virtualenvs3/risktables/lib/python3.9/site-packages/yfinance/multi.py:162, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, proxy, rounding, timeout, session, multi_level_index)
#     155         _download_one_threaded(ticker, period=period, interval=interval,
#     156                                start=start, end=end, prepost=prepost,
#     157                                actions=actions, auto_adjust=auto_adjust,
#     158                                back_adjust=back_adjust, repair=repair, keepna=keepna,
#     159                                progress=(progress and i > 0), proxy=proxy,
#     160                                rounding=rounding, timeout=timeout)
#     161     while len(shared._DFS) < len(tickers):
# --> 162         _time.sleep(0.01)
#     163 # download synchronously
#     164 else:
#     165     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:

# %%
# !jupyter nbconvert --to script yahoo_options.ipynb

# %% [markdown]
# ### Test below if the is any kind of correlation between:
# 1. percent changes in the stock price with changes in implied vol
# 2. binary changes in the value `up_down` with changes in implied vol
# 3. changes in 1 and 2 with the previous day's change in implied vol (lagged)

# %%
df_opt_all_hist_atm['pct_chg_price'] = df_opt_all_hist_atm.underlying.pct_change()
df_opt_all_hist_atm['iv_chg'] = df_opt_all_hist_atm.iv.diff()
display.display(df_opt_all_hist_atm[['pct_chg_price','iv_chg']].corr())
df_opt_all_hist_atm['up_down'] = df_opt_all_hist_atm.pct_chg_price/df_opt_all_hist_atm.pct_chg_price.abs()
display.display(df_opt_all_hist_atm[['up_down','iv_chg']].corr())
df_opt_all_hist_atm['lag_iv_chg'] = df_opt_all_hist_atm.iv_chg.shift(1)
display.display(df_opt_all_hist_atm[['up_down','lag_iv_chg']].corr())
display.display(df_opt_all_hist_atm[['pct_chg_price','lag_iv_chg']].corr())

# %% [markdown]
# ### Below are methods that:
# 1. get the *current* values of stock options,
# 2. show the break-even values for a simple strategy which purchases a one day ATM Strangle

# %%
dte = datetime.datetime.now()
dtb = datetime.datetime(2024,5,20)
yf.download('^VIX',dtb,dte)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price       Close       High        Low       Open Volume
# Ticker       ^VIX       ^VIX       ^VIX       ^VIX   ^VIX
# Date
# 2024-05-20  12.15  12.590000  12.070000  12.270000      0
# 2024-05-21  11.86  12.560000  11.840000  12.300000      0
# 2024-05-22  12.29  12.810000  11.780000  12.050000      0
# 2024-05-23  12.77  13.370000  11.520000  11.530000      0
# 2024-05-24  11.93  12.890000  11.890000  12.860000      0
# ...           ...        ...        ...        ...    ...
# 2025-08-05  17.85  18.940001  17.110001  17.209999      0
# 2025-08-06  16.77  17.879999  16.559999  17.219999      0
# 2025-08-07  16.57  17.639999  15.980000  16.410000      0
# 2025-08-08  15.15  16.520000  15.150000  16.480000      0
# 2025-08-11  15.82  16.129999  15.780000  15.810000      0
#
# [307 rows x 5 columns]

# %%
def get_stock_hist(sym,dte=None,dtb=None):
    if dte is None:
        dte = datetime.datetime.now()
    if dtb is None:
        dtb = datetime.datetime(2022,5,20)

    df_stock = yf.download(sym,dtb,dte)
    df_stock['pct_chg'] = df_stock.Close.pct_change()
    df_vix = yf.download('^VIX',dtb,dte)
    df_vix = df_vix.rename(columns={'Close':'VIX'})
    df_stock = df_stock.merge(df_vix[['VIX']],left_index=True,right_index=True)
    df_stock = df_stock.iloc[1:]
    return df_stock

def get_options_chain(
    underlying_symbol,
    mid_strk,
    strike_range=20,
    expiry_string=None,    
):
    if expiry_string is None:
        dt = datetime.datetime.now() + datetime.timedelta(1)
        ymd = str(dt.year*100*100+dt.month*100+dt.day)
        expiry_string = f"{ymd[0:4]}-{ymd[4:6]}-{ymd[6:8]}"
        
    low_strk = mid_strk - int(strike_range/2)
    high_strk = mid_strk + int(strike_range/2)
    strikes = np.arange(low_strk,high_strk+1).tolist()
    ticker = yf.Ticker(underlying_symbol)
    # ticker_options_chain = ticker.option_chain(date=None)
    ticker_options_chain = ticker.option_chain(date=expiry_string)
    dfc = ticker_options_chain[0]
    dfc2 = dfc[dfc.strike.isin(strikes)].copy()
    dfc2['mid'] = (dfc2.ask+dfc2.bid)/2

    dfp = ticker_options_chain[1]
    dfp2 = dfp[dfp.strike.isin(strikes)].copy()
    dfp2['mid'] = (dfp2.ask+dfp2.bid)/2
    return dfc2,dfp2

def strangle_strat(df_stock,dfc2,dfp2,ms):
    ps = ms - 2
    cs = ms + 2
    put = float(str(dfp2[dfp2.strike==ps].mid.values[0]))
    call = float(str(dfc2[dfc2.strike==cs].mid.values[0]))
    
    # returns is a dict of strategy parameters
    returns = {
        'strikes':[ps,cs,ms],
        'put_call':[put,call],
        'put_call_sum':put+call,
        'break_even_pct':(put+call+ms-ps)/ms,
        'strangle_premium':(put+call)/((ps+cs)/2),
        'strike_percents':[(ps-ms)/ms,(cs-ms)/ms],
        'opt_price_percents':[put/ms,call/ms]

    }

    df_stk2 = df_stock.copy()
    # pl_calc = lambda pct_chg: max(
    #     -1*returns['strangle_premium'],
    #     abs(pct_chg) - returns['break_even_pct']
    # ) 
    def pl_calc(pct_chg): 
        if abs(pct_chg)<returns['break_even_pct']:
            return -1*returns['strangle_premium']
        else:
            return abs(pct_chg) - returns['break_even_pct']


    df_stk2['pl'] = df_stk2.pct_chg.apply(pl_calc)

    df_stk2['cum_pl'] = df_stk2.pl.cumsum()
#     df_stk2[['pct_chg','pl','cum_pl']] 
    return returns,df_stk2


def get_condor_price(
    atm_price,
    vix,
    vix1d,
    rate = 0.045,
    dte = 2/365,
    put_skew_per_leg = .03,
    call_skew_per_leg = .005
):
    # F = 617
    # K = F
    # t = 1/365
    # r = .045
    # strike_width = 7
    # mid_sigma = .1265
    F = atm_price
    K = F
    t = dte
    r = rate
    # calc strike width
    strike_width = round(F*vix/16,0)
    mid_sigma = vix1d

    
    call_inner_sigma = mid_sigma - call_skew_per_leg
    put_inner_sigma = mid_sigma + put_skew_per_leg
    call_inner_price = black.black('c', F, K+strike_width, t, r, call_inner_sigma)
    put_inner_price = black.black('p', F, K-strike_width, t, r, put_inner_sigma)
    strangle_inner = call_inner_price + put_inner_price
    
    call_outer_sigma = mid_sigma - call_skew_per_leg*2
    put_outer_sigma = mid_sigma + put_skew_per_leg*2
    try:
        call_outer_price = black.black('c', F, K+strike_width*2, t, r, call_outer_sigma)
        put_outer_price = black.black('p', F, K-strike_width*2, t, r, put_outer_sigma)
    except Exception as e:
        print(str(e))
        dict_error = {
            'F':F,'K':K,'strike_width':strike_width,'t':t,'r':r,
            'call_outer_sigma':call_outer_sigma,'put_outer_sigma':put_outer_sigma
        }
        print(dict_error)
        pdb.set_trace()
        xxx = 1
        
    strangle_outer = call_outer_price + put_outer_price
    
    iron_condor = strangle_inner-strangle_outer
    
    dict_ret = {
        'put_inner_price':float(put_inner_price),
        'call_inner_price':float(call_inner_price),
        'strangle_inner':float(strangle_inner),
        'call_outer_price':float(call_outer_price),
        'put_outer_price':float(put_outer_price),
        'strangle_outer':float(strangle_outer),
        'iron_condor':float(iron_condor)
    }
    
    return dict_ret

def condor_strat():
    dte = datetime.datetime.now()
    dtb = dte - datetime.timedelta(2*365)
    df_sym_list_hist = get_stock_list_hist(['SPY','^VIX','^VIX1D'],dte,dtb,return_all_cols=True)
    # get ms mid_strike
    df_sym_list_hist['ms'] = [round(v,0) for v in df_sym_list_hist['Open_SPY'].values]
    # get daily call and put strikes
    df_sym_list_hist['vol1d_to_use'] = [v/16 for v in df_sym_list_hist['Open_^VIX'].values]
    df_sym_list_hist['strike_width'] = [round(row.ms*row.vol1d_to_use,0) for row in df_sym_list_hist]
    # condor inside strikes
    df_sym_list_hist['condor_cs_1'] = df_sym_list_hist.ms + df_sym_list_hist.strike_width
    df_sym_list_hist['condor_ps_1'] = df_sym_list_hist.ms - df_sym_list_hist.strike_width
    # condor outside strikes
    df_sym_list_hist['condor_cs_2'] = df_sym_list_hist.condor_cs_1 + df_sym_list_hist.strike_width
    df_sym_list_hist['condor_ps_2'] = df_sym_list_hist.condor_ps_1 - df_sym_list_hist.strike_width
    return df_sym_list_hist
#     ps = ms - 2
#     cs = ms + 2
#     put = float(str(dfp2[dfp2.strike==ps].mid.values[0]))
#     call = float(str(dfc2[dfc2.strike==cs].mid.values[0]))
    
#     # returns is a dict of strategy parameters
#     returns = {
#         'strikes':[ps,cs,ms],
#         'put_call':[put,call],
#         'put_call_sum':put+call,
#         'break_even_pct':(put+call+ms-ps)/ms,
#         'strangle_premium':(put+call)/((ps+cs)/2),
#         'strike_percents':[(ps-ms)/ms,(cs-ms)/ms],
#         'opt_price_percents':[put/ms,call/ms]

#     }

#     df_stk2 = df_stock.copy()
#     # pl_calc = lambda pct_chg: max(
#     #     -1*returns['strangle_premium'],
#     #     abs(pct_chg) - returns['break_even_pct']
#     # ) 
#     def pl_calc(pct_chg): 
#         if abs(pct_chg)<returns['break_even_pct']:
#             return -1*returns['strangle_premium']
#         else:
#             return abs(pct_chg) - returns['break_even_pct']


#     df_stk2['pl'] = df_stk2.pct_chg.apply(pl_calc)

#     df_stk2['cum_pl'] = df_stk2.pl.cumsum()

#     return returns,df_stk2

def plot_strat(df_stk2):
    df_stk3 = df_stk2.copy()
    df_stk3['yyyymmdd'] = [
        d.year*100*100+d.month*100+d.day
        for d in df_stk3.index.to_pydatetime()
    ]

    df_stk3['yyyymmdd'] = [
        d[0:4] + '-' + d[4:6] + '-' + d[6:8]
        for d in df_stk3.yyyymmdd.astype(str).values
    ]

    x_value_labels = [
        f"{d.year}-{('0'+str(d.month))[0:2]}-{('0'+str(d.day))[0:2]}"
        for d in df_stk3.index.to_pydatetime()
    ]

    df_stk3.index = list(range(len(df_stk3)))
    bdate = df_stk3.yyyymmdd.values[0]
    edate = df_stk3.yyyymmdd.values[-1]
    fig = pu.plotly_plot(
        df_stk3[['yyyymmdd','cum_pl']],
        'yyyymmdd',
        plot_title=f"Long Daily Strangle Strategy from {bdate} to {edate}"
    )
    return fig
    
def get_stock_list_hist(sym_list,dte=None,dtb=None,return_all_cols=False):
    if return_all_cols:
        df_all = None
        first_sym = 0
    else:
        df_all = get_stock_hist(sym_list[0],dte=dte,dtb=dtb)
        df_all = df_all[['Close']].rename(columns={'Close':sym_list[0]}).copy()
        first_sym = 1
    if len(sym_list)<2:
        return df_all
    for s in sym_list[first_sym:]:
        df_temp = get_stock_hist(s,dte=dte,dtb=dtb)
        if return_all_cols:
            dict_rename = {}
            df_temp.columns = df_temp.columns.get_level_values(0)
            for c in df_temp.columns.values:
                dict_rename[c] = c + "_" + s
            df_temp = df_temp.rename(columns=dict_rename)
        else:
            df_temp = df_temp[['Close']].rename(columns={'Close':s}).copy()
        if df_all is None:
            df_all = df_temp.copy()
        else:
            df_all = df_all.merge(df_temp,how='left',left_index=True,right_index=True)
    return df_all

# %%
dte = datetime.datetime.now()
dtb = dte - datetime.timedelta(2*365)
df_sym_list_hist_beg = get_stock_list_hist(['SPY','^VIX','^VIX1D'],dte,dtb,return_all_cols=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
def display_df_large_numbers(df,rounding=5,g_size=10):
    '''
    Display a dataframe without truncating number field types
    '''
    with pd.option_context('display.float_format',lambda x: f'%.{g_size}g' % x):
        display.display(df)

def is_number(s):
    try:
        poss_num = str_to_number(s)
        float(str(poss_num))
        return True
    except:
        return False

def str_to_number(value):
    if value is None:
        return None
    perc_divisor = 1
    pos_neg = 1
    s = str(value).strip().replace(' ','')
    s = s.replace('$','').replace(',','')
    if "(" in s:
        pos_neg = -1
    if '%' in s:
        perc_divisor =100
        s = s.replace('%','')
    s = s.replace('(','').replace(')','')
    try:
        float(s)
    except:
        v = str(value)
        v = v.replace('*','').strip()
        return v
    try:
        if ('.' in s) or (perc_divisor>1):
            return float(s.strip()) * pos_neg / perc_divisor
        return int(s.strip()) * pos_neg
    except:
        return str(value).replace(' **','')

def str_to_num_nan_is_0(s):
    if str(s).lower() == 'nan':
        return 0
    if str(s).lower() == '-':
        return 0
    
    return str_to_number(s)

# %%
df_sym_list_hist = df_sym_list_hist_beg.copy()
# get ms mid_strike
df_sym_list_hist['ms'] = [round(v,0) for v in df_sym_list_hist['Open_SPY'].values]
# get vol to use for strike width, and the strike width
df_sym_list_hist['vol1d_to_use'] = [v*.01 for v in df_sym_list_hist['Open_^VIX'].values]
# df_sym_list_hist['strike_width'] = [round(row['ms']*row['vol1d_to_use']/16,0) for row in df_sym_list_hist.to_dict(orient='records')]
df_sym_list_hist['strike_width'] = [int(row['ms']*row['vol1d_to_use']/16) for row in df_sym_list_hist.to_dict(orient='records')]
# condor inside strikes
df_sym_list_hist['condor_cs_1'] = df_sym_list_hist.ms + df_sym_list_hist.strike_width
df_sym_list_hist['condor_ps_1'] = df_sym_list_hist.ms - df_sym_list_hist.strike_width
# condor outside strikes
df_sym_list_hist['condor_cs_2'] = df_sym_list_hist.condor_cs_1 + df_sym_list_hist.strike_width
df_sym_list_hist['condor_ps_2'] = df_sym_list_hist.condor_ps_1 - df_sym_list_hist.strike_width
df_sym_list_hist['condor_info'] = [
    get_condor_price(row['ms'],row['Open_^VIX']/100,row['Open_^VIX1D']/100)['iron_condor']
    for row in df_sym_list_hist.to_dict(orient="records")
]
df_sym_list_hist['vix_to_vix1d_ratio'] = df_sym_list_hist['Open_^VIX']/df_sym_list_hist['Open_^VIX1D']
# get condor premium using ^Open_^VIX1D vol value, an approximate put and call skew, and the black scholes model
# get vix1d mid strike vol

# %%
display_df_large_numbers(df_sym_list_hist.iloc[-1],rounding=2,g_size=4)
# Out:
# Price
# Close_SPY               637.2
# High_SPY                637.7
# Low_SPY                 633.7
# Open_SPY                634.1
# Volume_SPY           6.39e+07
# pct_chg_SPY          0.007798
# VIX_SPY                 15.15
# Close_^VIX              15.15
# High_^VIX               16.52
# Low_^VIX                15.15
# Open_^VIX               16.48
# Volume_^VIX                 0
# pct_chg_^VIX          -0.0857
# VIX_^VIX                15.15
# Close_^VIX1D            10.86
# High_^VIX1D             11.19
# Low_^VIX1D               8.38
# Open_^VIX1D              8.46
# Volume_^VIX1D               0
# pct_chg_^VIX1D        -0.1291
# VIX_^VIX1D              15.15
# ms                        634
# vol1d_to_use           0.1648
# strike_width                6
# condor_cs_1               640
# condor_ps_1               628
# condor_cs_2               646
# condor_ps_2               622
# condor_info            0.2394
# vix_to_vix1d_ratio      1.948
# Name: 2025-08-08 00:00:00, dtype: float64

# %%
display.display(
    df_sym_list_hist[[
        'Open_SPY','Open_^VIX','Open_^VIX1D','ms','condor_info',
        # 'vol1d_to_use','strike_width','condor_cs_1','condor_ps_1','condor_cs_2','condor_ps_2'
    ]]
)
# Out:
# Price         Open_SPY  Open_^VIX  Open_^VIX1D     ms  condor_info
# Date
# 2023-08-15  434.699691  14.950000        10.15  435.0     0.397306
# 2023-08-16  430.988472  16.540001        10.62  431.0     0.433915
# 2023-08-17  429.722218  16.959999        10.43  430.0     0.276263
# 2023-08-18  422.134190  17.799999        12.25  422.0     0.415682
# 2023-08-21  426.205772  18.030001        10.91  426.0     0.306958
# ...                ...        ...          ...    ...          ...
# 2025-08-04  625.669983  19.559999         9.84  626.0     0.262034
# 2025-08-05  631.789978  17.209999         9.21  632.0     0.309897
# 2025-08-06  629.049988  17.219999         9.75  629.0     0.363383
# 2025-08-07  636.239990  16.410000         8.88  636.0     0.282499
# 2025-08-08  634.059998  16.480000         8.46  634.0     0.239432
#
# [498 rows x 5 columns]

# %%
_c1 = df_sym_list_hist.index>=datetime.datetime(2024,3,1)
_c2 = df_sym_list_hist.index<=datetime.datetime(2025,5,1)
df_sym_list_hist[_c1 & _c2].plot(y='vix_to_vix1d_ratio',figsize=(10, 7))
# Out:
# <Axes: xlabel='Date'>

# %%
df_sym_list_hist.tail(4)[['ms','Open_SPY','Open_^VIX','Open_^VIX1D']]
# Out:
# Price          ms    Open_SPY  Open_^VIX  Open_^VIX1D
# Date
# 2025-08-05  632.0  631.789978  17.209999         9.21
# 2025-08-06  629.0  629.049988  17.219999         9.75
# 2025-08-07  636.0  636.239990  16.410000         8.88
# 2025-08-08  634.0  634.059998  16.480000         8.46

# %%
get_condor_price(617,.16,.14,dte=1.5/365),get_condor_price(583,.21,.21,dte=1.5/365)
# Out:
# ({'put_inner_price': 0.6759818160496464,
#   'call_inner_price': 0.35504291118101966,
#   'strangle_inner': 1.031024727230666,
#   'call_outer_price': 0.018384289968822302,
#   'put_outer_price': 0.2133523978518251,
#   'strangle_outer': 0.2317366878206474,
#   'iron_condor': 0.7992880394100187},
#  {'put_inner_price': 0.8976316961274181,
#   'call_inner_price': 0.5984834173415104,
#   'strangle_inner': 1.4961151134689286,
#   'call_outer_price': 0.0474390762890639,
#   'put_outer_price': 0.22705356767246226,
#   'strangle_outer': 0.2744926439615262,
#   'iron_condor': 1.2216224695074023})

# %% [markdown]
# ### Use the methods above to show values for the one day strangle on SPY

# %%
import matplotlib.pyplot as plt

# %%
def condor_pl(row):
    close = row.Close_SPY
    condor_price = row.condor_info
    diff_spy = row.Close_SPY - row.Open_SPY

    pl_call_1 = max(row.Close_SPY - row.condor_cs_1,0)
    pl_call_2 = max(row.Close_SPY - row.condor_cs_2,0)
    pl_cs = pl_call_1 - pl_call_2

    pl_put_1 = max(row.condor_ps_1 - row.Close_SPY,0)
    pl_put_2 = max(row.condor_ps_2 - row.Close_SPY,0)
    pl_ps = pl_put_1 - pl_put_2

    pl_strat = -1 * (pl_cs + pl_ps) + condor_price
    return round(pl_strat,4)

df_sym_list_hist2 = df_sym_list_hist.copy()
_c1 = df_sym_list_hist2.index>=datetime.datetime(2023,3,1)
_c2 = df_sym_list_hist2.index<=datetime.datetime(2025,9,1)
df_sym_list_hist2 = df_sym_list_hist2[_c1 & _c2].copy()
df_sym_list_hist2['strat_pl']  = df_sym_list_hist2.apply(condor_pl,axis=1)
df_sym_list_hist2['cumulative_pl'] = df_sym_list_hist2.strat_pl.cumsum()

initial_investment = 300
df_sym_list_hist2['strat_perc']  = df_sym_list_hist2.strat_pl / initial_investment
df_sym_list_hist2['cumulative_perc'] = (1 + df_sym_list_hist2.strat_perc).cumprod()

plot_cols = [
    'ms','strike_width','condor_info','Close_SPY','Open_^VIX','Open_^VIX1D',
    'strat_pl','condor_cs_1','condor_cs_2','condor_ps_1','condor_ps_2'
]
# _c1 = df_sym_list_hist2.strat_pl < -8
# display_df_large_numbers(df_sym_list_hist2[_c1][plot_cols].iloc[0],rounding=2,g_size=4)

strat_sum = round(df_sym_list_hist2.strat_pl.sum(),2)
days = len(df_sym_list_hist2)
avg_condor_prem = df_sym_list_hist2.condor_info.mean()
print(
    {'strat pl':strat_sum,'days':days,'daily pl': strat_sum/days,'avg_condor_prem':avg_condor_prem}
)

ax1 = df_sym_list_hist2.plot(y='cumulative_pl',figsize=(10, 7))
ax1.grid(which='major',linestyle='--', linewidth=0.7, color='gray')
plt.show()

ax2 = df_sym_list_hist2.plot(y='cumulative_perc',figsize=(10, 7))
ax2.grid(which='major',linestyle='--', linewidth=0.7, color='gray')
plt.show()
# Out:
# {'strat pl': np.float64(128.18), 'days': 498, 'daily pl': np.float64(0.25738955823293175), 'avg_condor_prem': np.float64(0.547156495295085)}

# %%
def one_day_strangle():
    # pdb.set_trace()
    mid_strike = None#396
    # specify expiration string
    expiry_string =  None#'2023-03-24'
    
    # specify stock
    df_stock = get_stock_hist('SPY')
    
    # get close
    stock_close = df_stock.iloc[-1].Close.values[0]
    
    # get mid_strike
    if mid_strike is None:
        mid_strike = round(stock_close,0) if mid_strike is None else mid_strike
    
    # get expiry_string
    if expiry_string is None:
        n = datetime.datetime.now()
        wd = n.weekday()
        if wd>4:
            days_to_add = 7-wd
            n = n + datetime.timedelta(days_to_add)
        yyyymmdd = str(n.year*100*100 + n.month*100 + n.day)    
        expiry_string = yyyymmdd[0:4] + '-' + yyyymmdd[4:6] + '-' + yyyymmdd[6:8]
    
    # get calls and puts  
    df_calls,df_puts = get_options_chain('SPY',mid_strike,expiry_string=expiry_string)
    
    # display results
    expiry = df_calls.contractSymbol.iloc[0][:-9][-6:]
    display.display(f"stock_price = {stock_close}, mid strike = {mid_strike}, expiry: {expiry}")
    df_calls_and_puts = df_calls[['strike','mid']].merge(
        df_puts[['strike','mid']],how='left',on='strike'
    )
    df_calls_and_puts = df_calls_and_puts.rename(columns={'mid_x':'call','mid_y':'put'})
    display.display(df_calls_and_puts)
    strat_params,df_strat_results = strangle_strat(df_stock,df_calls,df_puts,mid_strike)
    display.display(strat_params)
    return {
        'stock_close':stock_close,
        'mid_strike':mid_strike,
        'expiry_string':expiry_string,
        'df_stock':df_stock,
        'df_calls':df_calls,
        'df_puts':df_puts,
        'df_calls_and_puts':df_calls_and_puts,
        'strat_params':strat_params,
        'df_strat_results':df_strat_results,
        
    }

# %%
dict_ods = one_day_strangle()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 'stock_price = 637.1799926757812, mid strike = 637.0, expiry: 250811'
#     strike  call  put
# 0    627.0   0.0  0.0
# 1    628.0   0.0  0.0
# 2    629.0   0.0  0.0
# 3    630.0   0.0  0.0
# 4    631.0   0.0  0.0
# 5    632.0   0.0  0.0
# 6    633.0   0.0  0.0
# 7    634.0   0.0  0.0
# 8    635.0   0.0  0.0
# 9    636.0   0.0  0.0
# 10   637.0   0.0  0.0
# 11   638.0   0.0  0.0
# 12   639.0   0.0  0.0
# 13   640.0   0.0  0.0
# 14   641.0   0.0  0.0
# 15   642.0   0.0  0.0
# 16   643.0   0.0  0.0
# 17   644.0   0.0  0.0
# 18   645.0   0.0  0.0
# 19   646.0   0.0  0.0
# 20   647.0   0.0  0.0
# {'strikes': [np.float64(635.0), np.float64(639.0), np.float64(637.0)],
#  'put_call': [0.0, 0.0],
#  'put_call_sum': 0.0,
#  'break_even_pct': np.float64(0.0031397174254317113),
#  'strangle_premium': np.float64(0.0),
#  'strike_percents': [np.float64(-0.0031397174254317113),
#   np.float64(0.0031397174254317113)],
#  'opt_price_percents': [np.float64(0.0), np.float64(0.0)]}

# %%
display.display(dict_ods['df_calls'])
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice  bid  ask  \
# 32  SPY250811C00627000 2025-08-08 20:07:25+00:00   627.0      10.88  0.0  0.0
# 33  SPY250811C00628000 2025-08-08 20:14:37+00:00   628.0      10.28  0.0  0.0
# 34  SPY250811C00629000 2025-08-08 20:14:37+00:00   629.0       9.31  0.0  0.0
# 35  SPY250811C00630000 2025-08-08 20:14:03+00:00   630.0       8.25  0.0  0.0
# 36  SPY250811C00631000 2025-08-08 20:14:37+00:00   631.0       7.40  0.0  0.0
# 37  SPY250811C00632000 2025-08-08 20:14:10+00:00   632.0       6.35  0.0  0.0
# 38  SPY250811C00633000 2025-08-08 20:14:38+00:00   633.0       5.55  0.0  0.0
# 39  SPY250811C00634000 2025-08-08 20:14:40+00:00   634.0       4.62  0.0  0.0
# 40  SPY250811C00635000 2025-08-08 20:14:59+00:00   635.0       3.83  0.0  0.0
# 41  SPY250811C00636000 2025-08-08 20:14:59+00:00   636.0       3.03  0.0  0.0
# 42  SPY250811C00637000 2025-08-08 20:14:59+00:00   637.0       2.30  0.0  0.0
# 43  SPY250811C00638000 2025-08-08 20:14:59+00:00   638.0       1.66  0.0  0.0
# 44  SPY250811C00639000 2025-08-08 20:14:59+00:00   639.0       1.16  0.0  0.0
# 45  SPY250811C00640000 2025-08-08 20:14:59+00:00   640.0       0.75  0.0  0.0
# 46  SPY250811C00641000 2025-08-08 20:14:59+00:00   641.0       0.46  0.0  0.0
# 47  SPY250811C00642000 2025-08-08 20:14:59+00:00   642.0       0.28  0.0  0.0
# 48  SPY250811C00643000 2025-08-08 20:14:59+00:00   643.0       0.15  0.0  0.0
# 49  SPY250811C00644000 2025-08-08 20:14:59+00:00   644.0       0.07  0.0  0.0
# 50  SPY250811C00645000 2025-08-08 20:14:54+00:00   645.0       0.04  0.0  0.0
# 51  SPY250811C00646000 2025-08-08 20:14:32+00:00   646.0       0.02  0.0  0.0
# 52  SPY250811C00647000 2025-08-08 20:14:59+00:00   647.0       0.02  0.0  0.0
#
#     change  percentChange   volume  openInterest  impliedVolatility  \
# 32     0.0            0.0    615.0           712           0.000010
# 33     0.0            0.0   1176.0          1474           0.000010
# 34     0.0            0.0    462.0          1610           0.000010
# 35     0.0            0.0   2617.0          1969           0.000010
# 36     0.0            0.0   3115.0           863           0.000010
# 37     0.0            0.0   4896.0          2399           0.000010
# 38     0.0            0.0  10102.0          6003           0.000010
# 39     0.0            0.0   9705.0          2616           0.000010
# 40     0.0            0.0  38270.0          6409           0.000010
# 41     0.0            0.0  61637.0          6493           0.000010
# 42     0.0            0.0  89547.0          8284           0.000010
# 43     0.0            0.0  87279.0          9633           0.007822
# 44     0.0            0.0  41971.0          9679           0.015635
# 45     0.0            0.0  55169.0         17230           0.015635
# 46     0.0            0.0  28682.0         10837           0.031260
# 47     0.0            0.0  22334.0         10354           0.031260
# 48     0.0            0.0  15694.0          7285           0.031260
# 49     0.0            0.0  10695.0          8848           0.062509
# 50     0.0            0.0  10931.0         12710           0.062509
# 51     0.0            0.0   2824.0          2641           0.062509
# 52     0.0            0.0   3174.0          3095           0.062509
#
#     inTheMoney contractSize currency  mid
# 32        True      REGULAR      USD  0.0
# 33        True      REGULAR      USD  0.0
# 34        True      REGULAR      USD  0.0
# 35        True      REGULAR      USD  0.0
# 36        True      REGULAR      USD  0.0
# 37        True      REGULAR      USD  0.0
# 38        True      REGULAR      USD  0.0
# 39        True      REGULAR      USD  0.0
# 40        True      REGULAR      USD  0.0
# 41        True      REGULAR      USD  0.0
# 42        True      REGULAR      USD  0.0
# 43       False      REGULAR      USD  0.0
# 44       False      REGULAR      USD  0.0
# 45       False      REGULAR      USD  0.0
# 46       False      REGULAR      USD  0.0
# 47       False      REGULAR      USD  0.0
# 48       False      REGULAR      USD  0.0
# 49       False      REGULAR      USD  0.0
# 50       False      REGULAR      USD  0.0
# 51       False      REGULAR      USD  0.0
# 52       False      REGULAR      USD  0.0

# %%
display.display(dict_ods['df_puts'])
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice  bid  ask  \
# 57  SPY250811P00627000 2025-08-08 20:14:47+00:00   627.0       0.11  0.0  0.0
# 58  SPY250811P00628000 2025-08-08 20:14:56+00:00   628.0       0.13  0.0  0.0
# 59  SPY250811P00629000 2025-08-08 20:14:41+00:00   629.0       0.14  0.0  0.0
# 60  SPY250811P00630000 2025-08-08 20:14:48+00:00   630.0       0.18  0.0  0.0
# 61  SPY250811P00631000 2025-08-08 20:14:59+00:00   631.0       0.22  0.0  0.0
# 62  SPY250811P00632000 2025-08-08 20:14:59+00:00   632.0       0.26  0.0  0.0
# 63  SPY250811P00633000 2025-08-08 20:14:59+00:00   633.0       0.34  0.0  0.0
# 64  SPY250811P00634000 2025-08-08 20:14:58+00:00   634.0       0.44  0.0  0.0
# 65  SPY250811P00635000 2025-08-08 20:14:59+00:00   635.0       0.56  0.0  0.0
# 66  SPY250811P00636000 2025-08-08 20:14:59+00:00   636.0       0.74  0.0  0.0
# 67  SPY250811P00637000 2025-08-08 20:14:59+00:00   637.0       1.01  0.0  0.0
# 68  SPY250811P00638000 2025-08-08 20:14:59+00:00   638.0       1.36  0.0  0.0
# 69  SPY250811P00639000 2025-08-08 20:14:59+00:00   639.0       1.83  0.0  0.0
# 70  SPY250811P00640000 2025-08-08 20:14:43+00:00   640.0       2.51  0.0  0.0
# 71  SPY250811P00641000 2025-08-08 20:14:59+00:00   641.0       3.15  0.0  0.0
# 72  SPY250811P00642000 2025-08-08 20:13:55+00:00   642.0       4.18  0.0  0.0
# 73  SPY250811P00643000 2025-08-08 20:06:15+00:00   643.0       5.37  0.0  0.0
# 74  SPY250811P00644000 2025-08-08 20:06:15+00:00   644.0       6.34  0.0  0.0
# 75  SPY250811P00645000 2025-08-08 20:13:57+00:00   645.0       7.00  0.0  0.0
# 76  SPY250811P00646000 2025-08-08 15:13:35+00:00   646.0      10.04  0.0  0.0
# 77  SPY250811P00647000 2025-08-08 16:23:57+00:00   647.0      10.05  0.0  0.0
#
#     change  percentChange    volume  openInterest  impliedVolatility  \
# 57     0.0            0.0    5989.0          3764           0.062509
# 58     0.0            0.0   13217.0          6561           0.062509
# 59     0.0            0.0   15207.0          6418           0.062509
# 60     0.0            0.0   34166.0         13520           0.062509
# 61     0.0            0.0   20333.0          3713           0.062509
# 62     0.0            0.0   24463.0          8451           0.031260
# 63     0.0            0.0   53521.0         14269           0.031260
# 64     0.0            0.0   41245.0          6970           0.031260
# 65     0.0            0.0   77020.0         15490           0.015635
# 66     0.0            0.0  104441.0         15606           0.007822
# 67     0.0            0.0   86518.0         14971           0.001963
# 68     0.0            0.0   21662.0          4206           0.000010
# 69     0.0            0.0    8802.0          1102           0.000010
# 70     0.0            0.0    5399.0          1682           0.000010
# 71     0.0            0.0    2046.0           811           0.000010
# 72     0.0            0.0    1584.0           986           0.000010
# 73     0.0            0.0     729.0            94           0.000010
# 74     0.0            0.0     135.0            44           0.000010
# 75     0.0            0.0     190.0            52           0.000010
# 76     0.0            0.0      12.0             6           0.000010
# 77     0.0            0.0     204.0             3           0.000010
#
#     inTheMoney contractSize currency  mid
# 57       False      REGULAR      USD  0.0
# 58       False      REGULAR      USD  0.0
# 59       False      REGULAR      USD  0.0
# 60       False      REGULAR      USD  0.0
# 61       False      REGULAR      USD  0.0
# 62       False      REGULAR      USD  0.0
# 63       False      REGULAR      USD  0.0
# 64       False      REGULAR      USD  0.0
# 65       False      REGULAR      USD  0.0
# 66       False      REGULAR      USD  0.0
# 67       False      REGULAR      USD  0.0
# 68        True      REGULAR      USD  0.0
# 69        True      REGULAR      USD  0.0
# 70        True      REGULAR      USD  0.0
# 71        True      REGULAR      USD  0.0
# 72        True      REGULAR      USD  0.0
# 73        True      REGULAR      USD  0.0
# 74        True      REGULAR      USD  0.0
# 75        True      REGULAR      USD  0.0
# 76        True      REGULAR      USD  0.0
# 77        True      REGULAR      USD  0.0

# %%
pvol.implied_volatility(1.51,621.13-.68,621,.045,1.5/365,'c')
# pvol.implied_volatility?
# Out:
# np.float64(0.11160534655754417)

# %%
_df_strat_results = dict_ods['df_strat_results']
_dtb = datetime.datetime(2025,1,1)
_dte = datetime.datetime.now()
_df_vix = yf.download('^VIX',_dtb,dte)
_df_vix = _df_vix.rename(columns={'Close':'VIX'})
_df_vix1d = yf.download('^VIX1D',_dtb,dte)
_df_vix1d = _df_vix1d.rename(columns={'Close':'VIX1D'})
df_vix_both = _df_vix['VIX'].merge(_df_vix1d['VIX1D'],left_index=True,right_index=True)
_c1 = _df_strat_results.index > _dtb
_df_strat_results = _df_strat_results[_c1]
# _df_strat_results = _df_strat_results.merge(_df_vix1d['VIX1D'],left_index=True,right_index=True)
# display.display(_df_strat_results)
# df_vix_both.columns = df_vix_both.columns.get_level_values(0)
df_vix_both = df_vix_both.reset_index()
df_vix_both['diff'] = df_vix_both['^VIX'] -  df_vix_both['^VIX1D']
display.display(df_vix_both.columns.values)
df_vix_both.to_csv('df_vix_30D_1D.csv',index=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# array(['Date', '^VIX', '^VIX1D', 'diff'], dtype=object)

# %%
# _df_strat_results = _df_strat_results.reset_index()
# _df_strat_results.columns = [tup[0] + ('_' + tup[1]) if len(tup[1])>0 else '' for tup in _df_strat_results.columns.values]
_df_strat_results.columns = [c[0] for c in _df_strat_results]
_df_strat_results
df_vix_both
# Out:
# Ticker       Date       ^VIX  ^VIX1D      diff
# 0      2025-01-02  17.930000   15.43  2.500000
# 1      2025-01-03  16.129999   11.59  4.539999
# 2      2025-01-06  16.040001   11.42  4.620001
# 3      2025-01-07  17.820000   14.25  3.570000
# 4      2025-01-08  17.700001   18.67 -0.969999
# ..            ...        ...     ...       ...
# 145    2025-08-04  17.520000   11.15  6.370001
# 146    2025-08-05  17.850000   12.31  5.540000
# 147    2025-08-06  16.770000   11.36  5.410001
# 148    2025-08-07  16.570000   12.47  4.099999
# 149    2025-08-08  15.150000   10.86  4.290000
#
# [150 rows x 4 columns]

# %%
calc_implied_vol?
# Out:
# Signature: calc_implied_vol(strike, opt_price, und_price, dte_perc_of_year, rate, pc)
# Docstring: <no docstring>
# File:      /var/folders/6c/341v5lbj2ms1zvq3z7p4df5r0000gn/T/ipykernel_39620/814732547.py
# Type:      function

# %%
calc_implied_vol(616,2.415,616.28,1.5/365,0.045,'c')
# Out:
# 0.14422993051984867

# %%
.25 + .15
# Out:
# 0.4

# %%
dict_ods['df_calls_and_puts']
# Out:
#     strike  call  put
# 0    627.0   0.0  0.0
# 1    628.0   0.0  0.0
# 2    629.0   0.0  0.0
# 3    630.0   0.0  0.0
# 4    631.0   0.0  0.0
# 5    632.0   0.0  0.0
# 6    633.0   0.0  0.0
# 7    634.0   0.0  0.0
# 8    635.0   0.0  0.0
# 9    636.0   0.0  0.0
# 10   637.0   0.0  0.0
# 11   638.0   0.0  0.0
# 12   639.0   0.0  0.0
# 13   640.0   0.0  0.0
# 14   641.0   0.0  0.0
# 15   642.0   0.0  0.0
# 16   643.0   0.0  0.0
# 17   644.0   0.0  0.0
# 18   645.0   0.0  0.0
# 19   646.0   0.0  0.0
# 20   647.0   0.0  0.0

# %% [markdown]
# ### Show correlations between VIX values and SPY changes

# %%
df_spy_vix = get_stock_list_hist(['SPY','^VIX','VIY00'])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Failed to get ticker 'VIY00' reason: 'str' object has no attribute 'name'
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['VIY00']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['^VIX']: AttributeError("'str' object has no attribute 'name'")

# %%
df_spy_vix['spy_pct_chg'] = df_spy_vix.SPY.pct_change()
df_spy_vix = df_spy_vix.iloc[1:]
df_spy_vix['vix_chg'] = df_spy_vix['^VIX'] - df_spy_vix['^VIX'].shift(1)
df_spy_vix[['spy_pct_chg','vix_chg']].copy().corr()
# Out:
# Price              spy_pct_chg   vix_chg
# Ticker
# Price       Ticker
# spy_pct_chg           1.000000 -0.758435
# vix_chg              -0.758435  1.000000

# %% [markdown]
# ### Show the distribution of stock percent changes over the period covered by the dataframe `df_stock`

# %%
df_stock.pct_chg.hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# ### use csv files extracted from the CME's FTP site to show the results of the strangle strategy above, but using the *ES* contracts on the CME, rather than the options on the *SPY*

# %%
yyyymmdd_of_zip = 20230410
filename = f"cme.settle.{yyyymmdd_of_zip}.s.csv.zip"

# %%
# Login to the FTP site
ftp = ftplib.FTP("ftp.cmegroup.com")
ftp.login()

# Change directory to the desired location
ftp.cwd("/pub/settle")

# Download the gzip file
dest_dir = 'temp_folder'
full_filename = f'{dest_dir}/{filename}'
with open(full_filename, "wb") as f:
    ftp.retrbinary("RETR " + filename, f.write)

ftp.quit()
    
# Define the input and output file names
input_file = full_filename
output_folder = dest_dir

# Create a ZipFile object for the input file
with zipfile.ZipFile(input_file, "r") as zip_ref:
    # Extract all contents of the input file to the output folder
    zip_ref.extractall(output_folder)

# Print a message indicating the file has been unzipped
print(f"{input_file} has been unzipped to {output_folder}.")
# Out:
# temp_folder/cme.settle.20230410.s.csv.zip has been unzipped to temp_folder.

# %%
def round_to_n(v,n):
    b = round(v/n,0)
    l = b*n
    h = (b+1)*n
    return l if (v - l) < (h - v) else h

# %%
yyyymmdd = 20230410
expiry_str = None
symbol_regex = None#'^E[12345]'
if symbol_regex is None:
    symbol_regex = '^E[12345]'
yyyy = str(yyyymmdd)[0:4]
mm = str(yyyymmdd)[4:6]
dd = str(yyyymmdd)[6:8]
if expiry_str is None:
    expiry_str = f'{yyyy}-{mm}-{dd}'
f = f'temp_folder/cme.settle.{yyyymmdd}.s.csv'
df_cme = pd.read_csv(f)

# get options
c1 = df_cme.Sym.str.contains(symbol_regex)
c2 = df_cme.MatDt > expiry_str
c3 = df_cme.SecTyp=='OOF'
c_all = c1 & c2 & c3
df_cme_options = df_cme[c_all].copy()

mat_dt = df_cme_options.MatDt.min()
c2 = df_cme.MatDt==mat_dt
c3 = df_cme.SecTyp=='OOF'
c_all = c1 & c2 & c3
df_cme_options = df_cme[c_all].copy()
display.display(df_cme_options[['MatDt','Sym']].drop_duplicates().sort_values(['MatDt','Sym']))
c1 = df_cme.Sym==df_cme_options.iloc[0]['UndlyID']
c3 = df_cme.SecTyp==df_cme_options.iloc[0]['UndlySecTyp']
c4 = df_cme.MMY == df_cme_options.iloc[0]['UndlyMMY']
c_all = c1 & c3 & c4

df_under = df_cme[c_all].copy()
future = df_under.iloc[0].SettlePrice
c3 = df_cme_options.SecTyp=='OOF'
c4 = df_cme_options.PutCall==0
c5 = df_cme_options.StrkPx <= future
c6 = df_cme_options.StrkPx >= future*.9
c_all = c3 & c4 & c5 & c6
cols = ['BizDt','StrkPx','PutCall','FixingPrice','SettlePrice','MatDt']
df_cme_puts = df_cme_options[c_all][cols]
c3 = df_cme_options.SecTyp=='OOF'
c4 = df_cme_options.PutCall==1
c5 = df_cme_options.StrkPx >= future
c6 = df_cme_options.StrkPx <= future*1.1
c_all = c3 & c4 & c5 & c6
df_cme_calls = df_cme_options[c_all][cols]

display.display(df_under[cols])
display.display(df_cme_puts[-5:])
display.display(df_cme_calls[:5])

# calculate break even percent
m = round_to_n(round(future),5)
put_price = df_cme_puts[df_cme_puts.StrkPx == (m-20)].iloc[0].SettlePrice
call_price = df_cme_calls[df_cme_calls.StrkPx == (m+20)].iloc[0].SettlePrice
be = (put_price + call_price + 20)/m
display.display(f"break even percent = {be}")
# Out:
#             MatDt  Sym
# 69548  2023-04-11  E2B
#             BizDt  StrkPx  PutCall  FixingPrice  SettlePrice       MatDt
# 76942  2023-04-10     NaN      NaN       4136.2      4136.25  2023-06-16
#             BizDt  StrkPx  PutCall  FixingPrice  SettlePrice       MatDt
# 69927  2023-04-10  4115.0      0.0          NaN         4.75  2023-04-11
# 69929  2023-04-10  4120.0      0.0          NaN         6.00  2023-04-11
# 69931  2023-04-10  4125.0      0.0          NaN         7.50  2023-04-11
# 69933  2023-04-10  4130.0      0.0          NaN         9.25  2023-04-11
# 69935  2023-04-10  4135.0      0.0          NaN        11.25  2023-04-11
#             BizDt  StrkPx  PutCall  FixingPrice  SettlePrice       MatDt
# 69936  2023-04-10  4140.0      1.0          NaN        10.00  2023-04-11
# 69938  2023-04-10  4145.0      1.0          NaN         7.75  2023-04-11
# 69940  2023-04-10  4150.0      1.0          NaN         6.00  2023-04-11
# 69942  2023-04-10  4155.0      1.0          NaN         4.60  2023-04-11
# 69944  2023-04-10  4160.0      1.0          NaN         3.45  2023-04-11
# 'break even percent = 0.0070979443772672315'
